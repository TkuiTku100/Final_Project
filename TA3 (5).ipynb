# %% [markdown]
# Before importing the next packages, be sure to install the following packages:
# python -m pip install sentence_transformers pinecone-client datasets

# %%
# !pip install sentence_transformers pinecone-client datasets
# Out:
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.10/dist-packages (5.0.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (10.4.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.8.30)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)

# %%
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
from pinecone import Pinecone, ServerlessSpec
import os
from tqdm import tqdm
import numpy as np
import warnings
from IPython.display import display
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # Change here to your own Pinecone API key, and the directory where you saved the trained model from file "model_training.ipynb"

# %%
PINECONE_API_KEY = "a28ff331-bc2b-41c0-b5bd-e1fc05448829"
save_directory = "./deberta_v3_base_model_enhanced"

# %%
from sentence_transformers import SentenceTransformer

EMBEDDING_MODEL = 'all-MiniLM-L6-v2'
embedding_model = SentenceTransformer(EMBEDDING_MODEL)

# %% [markdown]
# # Loading and Embedding the dataset

# %%
def load_and_embedd_dataset(
        dataset_name: str = 'hotpot_qa',
        split: str = 'train',
        model: SentenceTransformer = SentenceTransformer('all-MiniLM-L6-v2'),
        text_field: str = 'context',
        rec_num: int = 400,
        fraction: float = 0.15
) -> tuple:
    """
    Load a dataset and embedd the text field using a sentence-transformer model
    Args:
        dataset_name: The name of the dataset to load
        split: The split of the dataset to load
        model: The model to use for embedding
        text_field: The field in the dataset that contains the text
        rec_num: The number of records to load and embedd
    Returns:
        tuple: A tuple containing the dataset and the embeddings
    """
    from datasets import load_dataset

    print("Loading and embedding the dataset")

    # Load the dataset
    dataset = load_dataset(dataset_name, 'fullwiki', split=split)

    # Embed the first `rec_num` rows of the dataset
    embeddings = model.encode(dataset[text_field][:rec_num])

    print("Done!")
    return dataset, embeddings

# %%
DATASET_NAME = 'hotpot_qa'

dataset, embeddings = load_and_embedd_dataset(
    dataset_name=DATASET_NAME,
    split = 'validation',
    rec_num=40,
    model=embedding_model,
)
shape = embeddings.shape
# Out:
# Loading and embedding the dataset
# Done!

# %%
print(len(dataset)*0.15)
# Out:
# 1110.75

# %%
sample_indices = np.random.choice(len(dataset), size=int(len(dataset)*0.15), replace=False)
dataset=dataset.select(sample_indices)

# %%
pd_dataset = dataset.to_pandas()
pd_dataset.head(5)
# Out:
#                          id  \
# 0  5ab9c7c355429939ce03dc17
# 1  5a8f45385542997ba9cb320a
# 2  5a76fda05542994aec3b71b0
# 3  5a884adb5542996e4f308938
# 4  5a8b24f255429950cd6afc56
#
#                                             question                  answer  \
# 0  What regular performer at the R-26 club in Par...         Josephine Baker
# 1  Dahlia and Aruncus are both examples of what t...                   genus
# 2  Martin Flavin and Peter Benchley both did what...                novelist
# 3  Are Eryngium and Arnebia in the same kingdom o...                     yes
# 4  What retailer did Albert Heijn start up that e...  Koninklijke Ahold N.V.
#
#          type level                                   supporting_facts  \
# 0      bridge  hard  {'title': ['R-26 (salon)', 'Josephine Baker'],...
# 1  comparison  hard  {'title': ['Dahlia', 'Aruncus'], 'sent_id': [0...
# 2  comparison  hard  {'title': ['Martin Flavin', 'Peter Benchley'],...
# 3  comparison  hard  {'title': ['Eryngium', 'Arnebia'], 'sent_id': ...
# 4      bridge  hard  {'title': ['Albert Heijn (born 1927)', 'Ahold'...
#
#                                              context
# 0  {'title': ['Gregg Rogell', 'Cary Brothers', 'P...
# 1  {'title': ['Ayla-Axum amphorae', 'Tuber', 'Aru...
# 2  {'title': ['Laughing Sinners', 'Convicted (195...
# 3  {'title': ['Antarah ibn Shaddad', 'Ahimsa in J...
# 4  {'title': ['Food Lion', 'Albert Heijn', 'Ahold...

# %%
pd_dataset.shape
# Out:
# (1110, 7)

# %%
print(f"The embeddings shape: {embeddings.shape}")
# Out:
# The embeddings shape: (40, 384)

# %% [markdown]
# # Creating the Pinecone Index, and upserting the vectors of the data to it

# %%
def create_pinecone_index(
        index_name: str,
        dimension: int,
        metric: str = 'cosine',
):
    """
    Create a pinecone index if it does not exist
    Args:
        index_name: The name of the index
        dimension: The dimension of the index
        metric: The metric to use for the index
    Returns:
        Pinecone: A pinecone object which can later be used for upserting vectors and connecting to VectorDBs
    """
    from pinecone import Pinecone, ServerlessSpec
    print("Creating a Pinecone index...")
    pc = Pinecone(api_key=PINECONE_API_KEY)
    existing_indexes = [index_info["name"] for index_info in pc.list_indexes()]
    if index_name not in existing_indexes:
        pc.create_index(
            name=index_name,
            dimension=dimension,
            # Remember! It is crucial that the metric you will use in your VectorDB will also be a metric your embedding
            # model works well with!
            metric=metric,
            spec=ServerlessSpec(
                cloud="aws",
                region="us-east-1"
            )
        )
    print("Done!")
    return pc

# %%
def generate_embedding(text):
    return embedding_model.encode(text)

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ## Dataset Preparation includes changing rows of data to multiple ones, by each context.

# %%
from tqdm import tqdm
import numpy as np
def prepare_hotpotqa_data_for_upsert(dataset, batch_size: int = 128):

    print("Preparing embeddings and metadata for HotpotQA dataset...")

    embeddings = []
    meta_data = []
    ids = []
    counter = 0

    if isinstance(dataset, pd.DataFrame):
        dataset = dataset.to_dict('records')

    for i, row in tqdm(enumerate(dataset)):
        row_id = row.get('_id', f'row_{i}')

        context = row.get('context', {})
        titles = context.get('title', [])
        sentences_list = context.get('sentences', [])

        if len(titles) == len(sentences_list):
            for title, sentences in zip(titles, sentences_list):
                title = str(title)
                sentences = list(sentences)

                concatenated_sentences = " ".join(sentences)

                text_to_embed = concatenated_sentences
                embedding = generate_embedding(text_to_embed)

                supporting_facts = row.get('supporting_facts', [])
                if isinstance(supporting_facts, list):
                    supporting_facts = [list(fact) if isinstance(fact, (tuple, list)) else fact for fact in supporting_facts]

                metadata = {
                    'title': title,
                    'context': concatenated_sentences,
                    'question': row['question'],
                    'supporting_facts': supporting_facts,
                    'answer': row.get('answer', ''),
                    'level': row.get('level', '')
                }

                embeddings.append(embedding)
                meta_data.append(metadata)
                ids.append(f"{row_id}_{counter}")
                counter += 1
        else:
            print(f"Mismatch between titles and sentences at row {i}")

    embeddings = np.array(embeddings)

    to_upsert = list(zip(ids, embeddings, meta_data))

    print(f"Total items prepared: {len(to_upsert)}")
    return to_upsert

import pandas as pd

prepared_data = prepare_hotpotqa_data_for_upsert(pd_dataset)\

print(f"First 5 items:")
for i, item in enumerate(prepared_data[:5]):
    print(f"ID: {item[0]}, Metadata: {item[2]}")
# Out:
# Preparing embeddings and metadata for HotpotQA dataset...
# 1110it [15:13,  1.22it/s]
# Total items prepared: 11016
# ID: row_0_0, Metadata: {'title': 'Gregg Rogell', 'context': 'Gregg Rogell was born on February 18, 1967, in Long Island, New York, USA.  He is a professional comedian who resides in New York City.  He has appeared on "The Tonight Show, Late Night with Conan O\'Brien", and "The Nanny".  He has had his own half hour special on Comedy Central, and was a featured performer in the movie "The Aristocrats".  He is a regular performer at New York City\'s Comedy Cellar.', 'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?', 'supporting_facts': {'title': array(['R-26 (salon)', 'Josephine Baker'], dtype=object), 'sent_id': array([2, 4], dtype=int32)}, 'answer': 'Josephine Baker', 'level': 'hard'}
# ID: row_0_1, Metadata: {'title': 'Cary Brothers', 'context': 'Cary Brothers is an American indie rock singer-songwriter originally from Nashville, Tennessee, United States.  After moving to Los Angeles and becoming a regular performer at the influential Hotel Cafe venue, Brothers first gained national attention with his song "Blue Eyes" on the Platinum-selling, Grammy-winning "Garden State" soundtrack.  As an independent artist, he has since toured worldwide, released two full-length records, and become one of the most-licensed artists in film and television.  In the electronic dance music world, Brothers has collaborated with Tiësto on a club remix of his song "Ride" and an original song for Tiesto\'s album "Kaleidoscope", and he co-wrote and sang the title tracks for the Cosmic Gate releases "Wake Your Mind" and "Start to Feel".', 'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?', 'supporting_facts': {'title': array(['R-26 (salon)', 'Josephine Baker'], dtype=object), 'sent_id': array([2, 4], dtype=int32)}, 'answer': 'Josephine Baker', 'level': 'hard'}
# ID: row_0_2, Metadata: {'title': 'Patricia Racette', 'context': "Patricia Lynn Racette (born 1965) is an American operatic soprano.  A winner of the Richard Tucker Award in 1998, she has been a regular presence at major opera houses internationally.  Racette has enjoyed long-term partnerships with the San Francisco Opera, where she has been a regular performer since 1989, and with the Metropolitan Opera, where she has performed since 1995.  Also active on the concert stage, Racette has appeared with many of the world's leading orchestras, including the Boston Symphony Orchestra, the Chicago Symphony Orchestra, the San Francisco Symphony, and the London Philharmonic Orchestra.", 'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?', 'supporting_facts': {'title': array(['R-26 (salon)', 'Josephine Baker'], dtype=object), 'sent_id': array([2, 4], dtype=int32)}, 'answer': 'Josephine Baker', 'level': 'hard'}
# ID: row_0_3, Metadata: {'title': 'Kumar (Singaporean entertainer)', 'context': 'Kumarason Chinnadurai (born 10 August 1968, in Singapore), popularly known as Kumar, is a Singaporean Indian comedian and television host, actor, and drag queen.  He made his name at the now defunct Boom Boom Room and was, for a time, synonymous with the cabaret nightclub as its resident performer.  Having spent nearly two decades as an entertainer, he has amassed a string of television, stage, and film credits.  Currently, he is a regular performer at 3-Monkeys Café in Holland Village and Hard Rock Café.  He released his biographical book, "Kumar: From Rags To Drag", in September 2011, in which he publicly came out as gay, making him one of the few openly-gay public figures in Singapore.  He also discussed his then-twenty years in show business.', 'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?', 'supporting_facts': {'title': array(['R-26 (salon)', 'Josephine Baker'], dtype=object), 'sent_id': array([2, 4], dtype=int32)}, 'answer': 'Josephine Baker', 'level': 'hard'}
# ID: row_0_4, Metadata: {'title': 'Linda November', 'context': 'Linda Ellen November (born October\xa016,\xa01944) is an American singer who has sung tens of thousands of commercial jingles.  She was the voice of the singing cat in the Meow Mix commercials, sang the jingle "Galaxy Glue" in the 1981 film "The Incredible Shrinking Woman", the "Coke and a Smile" jingle in the classic Mean Joe Greene Super Bowl commercial, and has won many Clio Awards for her work on television and radio.  Her voice can also be heard on many pop songs, as she was a regular backup singer for artists such as Frankie Valli, Burt Bacharach, Engelbert Humperdinck, and Neil Diamond.  In the 1970s, she was one of the main singers in the disco group Wing and a Prayer Fife and Drum Corps, which charted with the Top 40 hit "Baby Face" in 1976.  In the 1980s and 1990s she was a regular performer in Atlantic City at The Grand and Harrah\'s, with her husband, composer and arranger Artie Schroeck.  As of 2011, she works as a piano accompanist in Las Vegas, Nevada.', 'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?', 'supporting_facts': {'title': array(['R-26 (salon)', 'Josephine Baker'], dtype=object), 'sent_id': array([2, 4], dtype=int32)}, 'answer': 'Josephine Baker', 'level': 'hard'}

# %%
from pinecone import Pinecone, ServerlessSpec
import numpy as np
from tqdm.auto import tqdm

def upsert_vectors(
        index: Pinecone,
        embeddings: np.ndarray,
        dataset: list,
        text_field: str = 'context',
        batch_size: int = 128
):

    print("Upserting the embeddings to the Pinecone index...")
    shape = embeddings.shape

    ids = [str(i) for i in range(shape[0])]

    meta = [{text_field: item[2][text_field]} for item in dataset]

    to_upsert = list(zip(ids, embeddings.tolist(), meta))

    for i in tqdm(range(0, shape[0], batch_size)):
        i_end = min(i + batch_size, shape[0])
        index.upsert(vectors=to_upsert[i:i_end])

    print("Upsert complete.")
    return index



INDEX_NAME = 'hotpotqa-final1'

pc = create_pinecone_index(INDEX_NAME, shape[1])

index = pc.Index(INDEX_NAME)

EMBEDDING_MODEL = 'all-MiniLM-L6-v2'
model = SentenceTransformer(EMBEDDING_MODEL)

rec_num = len(prepared_data)

context_texts = [item[2]['context'] for item in prepared_data]

embeddings = model.encode(context_texts[:rec_num])

index_upserted = upsert_vectors(index, np.array(embeddings), prepared_data)
# Out:
# Creating a Pinecone index...
# Done!
# Upserting the embeddings to the Pinecone index...
#   0%|          | 0/87 [00:00<?, ?it/s]
# Upsert complete.

# %%
dataset[0]
# Out:
# {'id': '5ab9c7c355429939ce03dc17',
#  'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?',
#  'answer': 'Josephine Baker',
#  'type': 'bridge',
#  'level': 'hard',
#  'supporting_facts': {'title': ['R-26 (salon)', 'Josephine Baker'],
#   'sent_id': [2, 4]},
#  'context': {'title': ['Gregg Rogell',
#    'Cary Brothers',
#    'Patricia Racette',
#    'Kumar (Singaporean entertainer)',
#    'Linda November',
#    'Virginia Biddle',
#    'Billy Pontoni',
#    "Herb Alpert's Vibrato Grill &amp; Jazz",
#    'Godfrey (comedian)',
#    'Stand Up for the Week'],
#   'sentences': [['Gregg Rogell was born on February 18, 1967, in Long Island, New York, USA.',
#     ' He is a professional comedian who resides in New York City.',
#     ' He has appeared on "The Tonight Show, Late Night with Conan O\'Brien", and "The Nanny".',
#     ' He has had his own half hour special on Comedy Central, and was a featured performer in the movie "The Aristocrats".',
#     " He is a regular performer at New York City's Comedy Cellar."],
#    ['Cary Brothers is an American indie rock singer-songwriter originally from Nashville, Tennessee, United States.',
#     ' After moving to Los Angeles and becoming a regular performer at the influential Hotel Cafe venue, Brothers first gained national attention with his song "Blue Eyes" on the Platinum-selling, Grammy-winning "Garden State" soundtrack.',
#     ' As an independent artist, he has since toured worldwide, released two full-length records, and become one of the most-licensed artists in film and television.',
#     ' In the electronic dance music world, Brothers has collaborated with Tiësto on a club remix of his song "Ride" and an original song for Tiesto\'s album "Kaleidoscope", and he co-wrote and sang the title tracks for the Cosmic Gate releases "Wake Your Mind" and "Start to Feel".'],
#    ['Patricia Lynn Racette (born 1965) is an American operatic soprano.',
#     ' A winner of the Richard Tucker Award in 1998, she has been a regular presence at major opera houses internationally.',
#     ' Racette has enjoyed long-term partnerships with the San Francisco Opera, where she has been a regular performer since 1989, and with the Metropolitan Opera, where she has performed since 1995.',
#     " Also active on the concert stage, Racette has appeared with many of the world's leading orchestras, including the Boston Symphony Orchestra, the Chicago Symphony Orchestra, the San Francisco Symphony, and the London Philharmonic Orchestra."],
#    ['Kumarason Chinnadurai (born 10 August 1968, in Singapore), popularly known as Kumar, is a Singaporean Indian comedian and television host, actor, and drag queen.',
#     ' He made his name at the now defunct Boom Boom Room and was, for a time, synonymous with the cabaret nightclub as its resident performer.',
#     ' Having spent nearly two decades as an entertainer, he has amassed a string of television, stage, and film credits.',
#     ' Currently, he is a regular performer at 3-Monkeys Café in Holland Village and Hard Rock Café.',
#     ' He released his biographical book, "Kumar: From Rags To Drag", in September 2011, in which he publicly came out as gay, making him one of the few openly-gay public figures in Singapore.',
#     ' He also discussed his then-twenty years in show business.'],
#    ['Linda Ellen November (born October\xa016,\xa01944) is an American singer who has sung tens of thousands of commercial jingles.',
#     ' She was the voice of the singing cat in the Meow Mix commercials, sang the jingle "Galaxy Glue" in the 1981 film "The Incredible Shrinking Woman", the "Coke and a Smile" jingle in the classic Mean Joe Greene Super Bowl commercial, and has won many Clio Awards for her work on television and radio.',
#     ' Her voice can also be heard on many pop songs, as she was a regular backup singer for artists such as Frankie Valli, Burt Bacharach, Engelbert Humperdinck, and Neil Diamond.',
#     ' In the 1970s, she was one of the main singers in the disco group Wing and a Prayer Fife and Drum Corps, which charted with the Top 40 hit "Baby Face" in 1976.',
#     " In the 1980s and 1990s she was a regular performer in Atlantic City at The Grand and Harrah's, with her husband, composer and arranger Artie Schroeck.",
#     ' As of 2011, she works as a piano accompanist in Las Vegas, Nevada.'],
#    ['Virginia Biddle (1910–2003) was an American revue performer and showgirl.',
#     ' Biddle was a regular performer in Florenz Ziegfeld\'s "Follies" shows until 1931.'],
#    ['Billy Pontoni, (born 1954) or Guillermo García, joined the Pedro Morales Pino conservatory in his hometown Cartago, Colombia as a child.',
#     ' Then he became one of the artists from the Youths Club in Radio Cartago, in which he made his first appearances as a singer.',
#     ' In 1966 he arrived to Bogotá searching for an opportunity.',
#     ' There he became a regular performer at the Club del Clan TV Show, where his name was changed to Billy.',
#     ' At 14 he signed a contract with the Grill El Caracol Rojo as lead vocalist.'],
#    ["Herb Alpert's Vibrato Grill & Jazz is a jazz club and restaurant on Beverly Glen Circle in Bel Air, Los Angeles, to the south of Mulholland Drive.",
#     ' It was established by Grammy Award-winning jazz trumpeter Herb Alpert.',
#     ' Ariana Savalas is a regular performer at the club.'],
#    ['Godfrey C. Danchimah, Jr. (born July 21, 1969), professionally known as Godfrey, is an American comedian and actor who has appeared on BET, VH1, Comedy Central, and feature films, such as "Soul Plane", "Original Gangstas", "Zoolander", and "Johnson Family Vacation".',
#     " He was also a spokesperson for 7 Up during the popular '7up yours' advertising campaign.",
#     ' He was also a cast member on the first season of "The It Factor", a reality television show.',
#     ' Currently, he is a regular performer at the comedy club Comedy Cellar in New York City.',
#     ' He is also known for doing the voices of Mr. Stubborn and Mr. Tall (Season 2) in "The Mr. Men Show" and hosting the FOX game show "Bullseye".',
#     ' Godfrey also hosts his own Radio Show on SiriusXM.'],
#    ['Stand Up for the Week is a British television comedy series that was shown on Channel 4, featuring stand-up comedy performances reflecting topical events.',
#     ' The show began in June 2010 with a six-episode series aired on Friday nights, moving to Saturday nights for the second series which began in March 2011.',
#     ' The first series was hosted by Patrick Kielty, with regular performers Jack Whitehall, Kevin Bridges, Andi Osho and Rich Hall.',
#     ' Bridges replaced Kielty as host for the second series, with Jon Richardson joining as a regular performer.',
#     ' Richardson took over as host of the show for the third series which aired in late 2011, and aside from Rich Hall returning, an otherwise entirely new group of regular performers joined the show: Seann Walsh, Sara Pascoe, Josh Widdicombe and Paul Chowdhry.',
#     ' For the fourth series Andrew Lawrence replaced Rich Hall.',
#     ' For the fifth series, Chowdhry took over as host and new regulars Angela Barnes, Simon Evans and Romesh Ranganathan replaced Chowdhry, Lawrence and Pascoe.',
#     ' In October 2015 Channel 4 confirmed there are no plans to produce more episodes of the show.']]}}

# %% [markdown]
# # Test of pinecone index retrieval

# %%
query_text = "Were Scott Derrickson and Ed Wood of the same nationality?"
query_embedding = embedding_model.encode([query_text])[0]
print(f"Query Embedding Shape: {query_embedding.shape}")  # Should print (384,)
# Out:
# Query Embedding Shape: (384,)

# %%
results = [float(val) for val in list(embedding_model.encode(query_text))]
query_results = index.query(
    vector=results,
    top_k=3,
    include_values=True,
    include_metadata=True
)['matches']
print(query_results)
# Out:
# [{'id': '7498',
#  'metadata': {'context': 'Ed Wood is a 1994 American biographical period '
#                          'comedy-drama film directed and produced by Tim '
#                          'Burton, and starring Johnny Depp as cult filmmaker '
#                          "Ed Wood.  The film concerns the period in Wood's "
#                          'life when he made his best-known films as well as '
#                          'his relationship with actor Bela Lugosi, played by '
#             -0.000519741385,
#             0.0155665511,
#             -0.0428079404,
#             -0.0398648977,
#             -0.0435488373,
#             -0.0786089376,
#             -0.0239177905,
#             -0.0922371149,
#             0.100529782,
#             0.049990315,
#             0.0217246283,
#             0.0277882442,
#             0.0266604275,
#             0.123439305,
#             0.0517088883,
#             -0.098711513,
#             0.0425516702,
#             -0.0785745606,
#             0.0664910451,
#             0.00358580635,
#             0.0295809899,
#             -0.0771472529,
#             -0.0708515272,
#             0.0300998148,
#             -0.0154066849,
#             -0.0429143868,
#             -0.00859236065,
#             -0.0393352173,
#             -0.00379322981,
#             -0.0648500919,
#             0.0144670783]}]

# %%
# import torch
# import numpy as np
# from transformers import AutoTokenizer, AutoModelForQuestionAnswering
# from sentence_transformers import SentenceTransformer
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# tokenizer1 = AutoTokenizer.from_pretrained("sjrhuschlee/deberta-v3-base-squad2-ext-v1")
# model1 = AutoModelForQuestionAnswering.from_pretrained("sjrhuschlee/deberta-v3-base-squad2-ext-v1")

# embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# def answer_query_with_context(query, true_answer, pinecone_index, top_k=3):
#     """
#     Retrieve the top contexts from Pinecone, run the QA model on those contexts,
#     and compare the generated answer with the true answer.

#     Args:
#         query (str): The question/query.
#         true_answer (str): The true answer for comparison.
#         pinecone_index: The Pinecone index object for retrieving contexts.
#         top_k (int): The number of top contexts to retrieve from Pinecone.

#     Returns:
#         None: Prints the best generated answer and its similarity with the true answer.
#     """
#     # Convert the query into an embedding using SentenceTransformer
#     query_embedding = embedding_model.encode(query)

#     # Convert the embedding to a list of floats (for Pinecone query)
#     query_vector = [float(val) for val in list(query_embedding)]

#     # Retrieve top contexts from Pinecone
#     query_results = pinecone_index.query(
#         vector=query_vector,
#         top_k=top_k,
#         include_values=True,
#         include_metadata=True
#     )['matches']

#     best_generated_answer = ""
#     best_similarity = -1.0

#     # Iterate over retrieved contexts and evaluate the model on each one
#     for match in query_results:
#         context = match['metadata']['context']  # Extract context from metadata

#         # Tokenize the question and context
#         inputs = tokenizer(query, context, return_tensors="pt", max_length=512, truncation=True)

#         # Perform inference to predict start and end positions
#         with torch.no_grad():
#             outputs = model(**inputs)
#             start_logits = outputs.start_logits
#             end_logits = outputs.end_logits

#             # Get the most probable start and end positions
#             start_idx = torch.argmax(start_logits)
#             end_idx = torch.argmax(end_logits)

#             # Check if the predicted indices are valid
#             if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
#                 generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
#             else:
#                 generated_answer = ""  # If indices are invalid, return an empty string

#             # Calculate similarity between the generated answer and the true answer
#             if generated_answer:
#                 vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
#                 similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]
#             else:
#                 similarity = 0.0  # No answer means zero similarity

#             # Track the best answer based on similarity
#             if similarity > best_similarity:
#                 best_generated_answer = generated_answer
#                 best_similarity = similarity

#     # Print the results
#     print(f"Query: {query}")
#     print(f"Best Generated Answer: {best_generated_answer}")
#     print(f"True Answer: {true_answer}")
#     print(f"Best Similarity: {best_similarity}\n")

# # Example usage:

# # for query_text, true_answer in:
# query_text = "Were Scott Derrickson and Ed Wood of the same nationality?"
# true_answer = "yes"  # You can modify this if you have the correct answer

# # Assuming `index` is the Pinecone index you used earlier
# answer_query_with_context(query_text, true_answer, pinecone_index=index, top_k=3)
# Out:
# Query: Were Scott Derrickson and Ed Wood of the same nationality?
# Best Generated Answer:
# True Answer: yes
# Best Similarity: 0.0

# %%
dataset[0]
# Out:
# {'id': '5ab9c7c355429939ce03dc17',
#  'question': 'What regular performer at the R-26 club in Paris was known for her banana-themed costume?',
#  'answer': 'Josephine Baker',
#  'type': 'bridge',
#  'level': 'hard',
#  'supporting_facts': {'title': ['R-26 (salon)', 'Josephine Baker'],
#   'sent_id': [2, 4]},
#  'context': {'title': ['Gregg Rogell',
#    'Cary Brothers',
#    'Patricia Racette',
#    'Kumar (Singaporean entertainer)',
#    'Linda November',
#    'Virginia Biddle',
#    'Billy Pontoni',
#    "Herb Alpert's Vibrato Grill &amp; Jazz",
#    'Godfrey (comedian)',
#    'Stand Up for the Week'],
#   'sentences': [['Gregg Rogell was born on February 18, 1967, in Long Island, New York, USA.',
#     ' He is a professional comedian who resides in New York City.',
#     ' He has appeared on "The Tonight Show, Late Night with Conan O\'Brien", and "The Nanny".',
#     ' He has had his own half hour special on Comedy Central, and was a featured performer in the movie "The Aristocrats".',
#     " He is a regular performer at New York City's Comedy Cellar."],
#    ['Cary Brothers is an American indie rock singer-songwriter originally from Nashville, Tennessee, United States.',
#     ' After moving to Los Angeles and becoming a regular performer at the influential Hotel Cafe venue, Brothers first gained national attention with his song "Blue Eyes" on the Platinum-selling, Grammy-winning "Garden State" soundtrack.',
#     ' As an independent artist, he has since toured worldwide, released two full-length records, and become one of the most-licensed artists in film and television.',
#     ' In the electronic dance music world, Brothers has collaborated with Tiësto on a club remix of his song "Ride" and an original song for Tiesto\'s album "Kaleidoscope", and he co-wrote and sang the title tracks for the Cosmic Gate releases "Wake Your Mind" and "Start to Feel".'],
#    ['Patricia Lynn Racette (born 1965) is an American operatic soprano.',
#     ' A winner of the Richard Tucker Award in 1998, she has been a regular presence at major opera houses internationally.',
#     ' Racette has enjoyed long-term partnerships with the San Francisco Opera, where she has been a regular performer since 1989, and with the Metropolitan Opera, where she has performed since 1995.',
#     " Also active on the concert stage, Racette has appeared with many of the world's leading orchestras, including the Boston Symphony Orchestra, the Chicago Symphony Orchestra, the San Francisco Symphony, and the London Philharmonic Orchestra."],
#    ['Kumarason Chinnadurai (born 10 August 1968, in Singapore), popularly known as Kumar, is a Singaporean Indian comedian and television host, actor, and drag queen.',
#     ' He made his name at the now defunct Boom Boom Room and was, for a time, synonymous with the cabaret nightclub as its resident performer.',
#     ' Having spent nearly two decades as an entertainer, he has amassed a string of television, stage, and film credits.',
#     ' Currently, he is a regular performer at 3-Monkeys Café in Holland Village and Hard Rock Café.',
#     ' He released his biographical book, "Kumar: From Rags To Drag", in September 2011, in which he publicly came out as gay, making him one of the few openly-gay public figures in Singapore.',
#     ' He also discussed his then-twenty years in show business.'],
#    ['Linda Ellen November (born October\xa016,\xa01944) is an American singer who has sung tens of thousands of commercial jingles.',
#     ' She was the voice of the singing cat in the Meow Mix commercials, sang the jingle "Galaxy Glue" in the 1981 film "The Incredible Shrinking Woman", the "Coke and a Smile" jingle in the classic Mean Joe Greene Super Bowl commercial, and has won many Clio Awards for her work on television and radio.',
#     ' Her voice can also be heard on many pop songs, as she was a regular backup singer for artists such as Frankie Valli, Burt Bacharach, Engelbert Humperdinck, and Neil Diamond.',
#     ' In the 1970s, she was one of the main singers in the disco group Wing and a Prayer Fife and Drum Corps, which charted with the Top 40 hit "Baby Face" in 1976.',
#     " In the 1980s and 1990s she was a regular performer in Atlantic City at The Grand and Harrah's, with her husband, composer and arranger Artie Schroeck.",
#     ' As of 2011, she works as a piano accompanist in Las Vegas, Nevada.'],
#    ['Virginia Biddle (1910–2003) was an American revue performer and showgirl.',
#     ' Biddle was a regular performer in Florenz Ziegfeld\'s "Follies" shows until 1931.'],
#    ['Billy Pontoni, (born 1954) or Guillermo García, joined the Pedro Morales Pino conservatory in his hometown Cartago, Colombia as a child.',
#     ' Then he became one of the artists from the Youths Club in Radio Cartago, in which he made his first appearances as a singer.',
#     ' In 1966 he arrived to Bogotá searching for an opportunity.',
#     ' There he became a regular performer at the Club del Clan TV Show, where his name was changed to Billy.',
#     ' At 14 he signed a contract with the Grill El Caracol Rojo as lead vocalist.'],
#    ["Herb Alpert's Vibrato Grill & Jazz is a jazz club and restaurant on Beverly Glen Circle in Bel Air, Los Angeles, to the south of Mulholland Drive.",
#     ' It was established by Grammy Award-winning jazz trumpeter Herb Alpert.',
#     ' Ariana Savalas is a regular performer at the club.'],
#    ['Godfrey C. Danchimah, Jr. (born July 21, 1969), professionally known as Godfrey, is an American comedian and actor who has appeared on BET, VH1, Comedy Central, and feature films, such as "Soul Plane", "Original Gangstas", "Zoolander", and "Johnson Family Vacation".',
#     " He was also a spokesperson for 7 Up during the popular '7up yours' advertising campaign.",
#     ' He was also a cast member on the first season of "The It Factor", a reality television show.',
#     ' Currently, he is a regular performer at the comedy club Comedy Cellar in New York City.',
#     ' He is also known for doing the voices of Mr. Stubborn and Mr. Tall (Season 2) in "The Mr. Men Show" and hosting the FOX game show "Bullseye".',
#     ' Godfrey also hosts his own Radio Show on SiriusXM.'],
#    ['Stand Up for the Week is a British television comedy series that was shown on Channel 4, featuring stand-up comedy performances reflecting topical events.',
#     ' The show began in June 2010 with a six-episode series aired on Friday nights, moving to Saturday nights for the second series which began in March 2011.',
#     ' The first series was hosted by Patrick Kielty, with regular performers Jack Whitehall, Kevin Bridges, Andi Osho and Rich Hall.',
#     ' Bridges replaced Kielty as host for the second series, with Jon Richardson joining as a regular performer.',
#     ' Richardson took over as host of the show for the third series which aired in late 2011, and aside from Rich Hall returning, an otherwise entirely new group of regular performers joined the show: Seann Walsh, Sara Pascoe, Josh Widdicombe and Paul Chowdhry.',
#     ' For the fourth series Andrew Lawrence replaced Rich Hall.',
#     ' For the fifth series, Chowdhry took over as host and new regulars Angela Barnes, Simon Evans and Romesh Ranganathan replaced Chowdhry, Lawrence and Pascoe.',
#     ' In October 2015 Channel 4 confirmed there are no plans to produce more episodes of the show.']]}}

# %% [markdown]
# # Evaluation on Pre-Trained Deberta based, HotpotQA fine-tuned model, with average similarity and Exact Match (EM) calculations.

# %%
import json
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


tokenizer = AutoTokenizer.from_pretrained("sjrhuschlee/deberta-v3-base-squad2-ext-v1")
qa_model = AutoModelForQuestionAnswering.from_pretrained("sjrhuschlee/deberta-v3-base-squad2-ext-v1")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

sim1=[]

def answer_query_with_context(query, true_answer, pinecone_index, top_k=5):
    query_embedding = embedding_model.encode(query)
    query_vector = [float(val) for val in query_embedding]

    query_results = pinecone_index.query(
        vector=query_vector,
        top_k=top_k,
        include_metadata=True
    )['matches']

    best_generated_answer = ""
    best_similarity = -1.0

    for match in query_results:
        context = match['metadata']['context']

        inputs = tokenizer(query, context, return_tensors="pt", max_length=512, truncation=True)

        with torch.no_grad():
            outputs = qa_model(**inputs)
            start_idx = torch.argmax(outputs.start_logits)
            end_idx = torch.argmax(outputs.end_logits)

            if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
                generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
            else:
                generated_answer = ""

            if generated_answer:
                vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
                similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]
            else:
                similarity = 0.0

            if similarity > best_similarity:
                best_generated_answer = generated_answer
                best_similarity = similarity

    return best_generated_answer, best_similarity

def answer_query_with_context2(query, true_answer, pinecone_index, top_k=5):
    query_embedding = embedding_model.encode(query)
    query_vector = [float(val) for val in query_embedding]

    query_results = pinecone_index.query(
        vector=query_vector,
        top_k=top_k,
        include_metadata=True
    )['matches']

    best_generated_answer = ""
    best_similarity = -1.0

    for match in query_results:
        context = match['metadata']['context']
        context_segments = context.split(". ")

        for segment in context_segments:
            inputs = tokenizer(query, segment, return_tensors="pt", max_length=512, truncation=True)
            with torch.no_grad():
                outputs = qa_model(**inputs)
                start_idx = torch.argmax(outputs.start_logits)
                end_idx = torch.argmax(outputs.end_logits)

                if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
                    generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
                else:
                    generated_answer = ""

                if generated_answer:
                    vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
                    similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]
                else:
                    similarity = 0.0

                if similarity > best_similarity:
                    best_generated_answer = generated_answer
                    best_similarity = similarity

    return best_generated_answer, best_similarity


def save_first_100_answers_from_hotpotqa(hotpotqa_data, pinecone_index, file_name="qa_results.json"):
    results = []

    for i in range(100):
        query = hotpotqa_data[i]["question"]
        true_answer = hotpotqa_data[i]["answer"]

        generated_answer, similarity = answer_query_with_context2(query, true_answer, pinecone_index)

        results.append({
            "question": query,
            "true_answer": true_answer,
            "generated_answer": generated_answer,
            "similarity": similarity
        })

        print(f"Processed question {i+1}:")
        print(f"Generated Answer: {generated_answer}")
        print(f"True Answer: {true_answer}")
        print(f"Similarity: {similarity}\n")
        sim1.append(similarity)

    with open(file_name, "w") as f:
        json.dump(results, f, indent=4)
    print(f"Results saved to {file_name}")

save_first_100_answers_from_hotpotqa(dataset, pinecone_index=index)
print(np.mean(sim1))

# %%
print(sim1)
count=0
for i in sim1:
  if i>=1:
    count+=1
print(count/len(sim1))

# %% [markdown]
# # Evaluation on our proposed model, as trained in "model_training.ipynb", with average similarity and Exact Match (EM) calculations.

# %%
import json
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sim1=[]

tokenizer = AutoTokenizer.from_pretrained(save_directory)
qa_model = AutoModelForQuestionAnswering.from_pretrained(save_directory)

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

def answer_query_with_context3(query, true_answer, pinecone_index, top_k=3):

    query_embedding = embedding_model.encode(query)
    query_vector = [float(val) for val in query_embedding]

    query_results = pinecone_index.query(
        vector=query_vector,
        top_k=top_k,
        include_values=True,
        include_metadata=True
    )['matches']

    best_generated_answer = ""
    best_combined_score = -1.0

    for match in query_results:
        context = match['metadata']['context']
        sentences = context.split(". ")

        for sentence in sentences:
            inputs = tokenizer(query, sentence, return_tensors="pt", max_length=512, truncation=True)

            with torch.no_grad():
                outputs = model(**inputs)
                start_logits = outputs.start_logits
                end_logits = outputs.end_logits

                start_idx = torch.argmax(start_logits)
                end_idx = torch.argmax(end_logits)

                if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
                    generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
                else:
                    generated_answer = ""

                if generated_answer:
                    vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
                    similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]

                    confidence = (start_logits[0][start_idx] + end_logits[0][end_idx]).item()
                    combined_score = similarity * confidence

                    if combined_score > best_combined_score:
                        best_generated_answer = generated_answer
                        best_combined_score = combined_score

    print(f"Query: {query}")
    print(f"Best Generated Answer: {best_generated_answer}")
    print(f"True Answer: {true_answer}")
    print(f"Best Combined Score (Similarity x Confidence): {best_combined_score}\n")
    return best_generated_answer, best_combined_score

def save_first_100_answers_from_hotpotqa2(hotpotqa_data, pinecone_index, file_name="qa_results.json"):
    results = []

    for i in range(len(hotpotqa_data)):
        query = hotpotqa_data[i]["question"]
        true_answer = hotpotqa_data[i]["answer"]

        generated_answer, similarity = answer_query_with_context3(query, true_answer, pinecone_index)

        results.append({
            "question": query,
            "true_answer": true_answer,
            "generated_answer": generated_answer,
            "similarity": similarity
        })

        print(f"Processed question {i+1}:")
        print(f"Generated Answer: {generated_answer}")
        print(f"True Answer: {true_answer}")
        print(f"Similarity: {similarity}\n")
        sim1.append(similarity)

    with open(file_name, "w") as f:
        json.dump(results, f, indent=4)
    print(f"Results saved to {file_name}")

save_first_100_answers_from_hotpotqa2(dataset, pinecone_index=index)
print(np.mean(sim1))
# Out:
# Query: What regular performer at the R-26 club in Paris was known for her banana-themed costume?
# Best Generated Answer: What regular performer at the R-26 club in Paris was known for her banana-themed costume? Patrick Kelly
# True Answer: Josephine Baker
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 1:
# Generated Answer: What regular performer at the R-26 club in Paris was known for her banana-themed costume? Patrick Kelly
# True Answer: Josephine Baker
# Similarity: -0.0
#
# Query: Dahlia and Aruncus are both examples of what type of plant catagorization?
# Best Generated Answer:
# True Answer: genus
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 2:
# Generated Answer:
# True Answer: genus
# Similarity: -1.0
#
# Query: Martin Flavin and Peter Benchley both did what occupation?
# Best Generated Answer: Member of Parliament
# True Answer: novelist
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 3:
# Generated Answer: Member of Parliament
# True Answer: novelist
# Similarity: 0.0
#
# Query: Are Eryngium and Arnebia in the same kingdom of life forms?
# Best Generated Answer: Arbutus
# True Answer: yes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 4:
# Generated Answer: Arbutus
# True Answer: yes
# Similarity: 0.0
#
# Query: What retailer did Albert Heijn start up that eventually merged with the Delhaize Group?
# Best Generated Answer: largest food retailer in the Netherlands
# True Answer: Koninklijke Ahold N.V.
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 5:
# Generated Answer: largest food retailer in the Netherlands
# True Answer: Koninklijke Ahold N.V.
# Similarity: 0.0
#
# Query: What was the name of the 1996 loose adaptation of William Shakespeare's "Romeo & Juliet" written by James Gunn?
# Best Generated Answer: Tromeo and Juliet
# True Answer: Tromeo and Juliet
# Best Combined Score (Similarity x Confidence): 15.781793594360355
#
# Processed question 6:
# Generated Answer: Tromeo and Juliet
# True Answer: Tromeo and Juliet
# Similarity: 15.781793594360355
#
# Query: The Pluralist school is said to have included what creator of the theory of atomism?
# Best Generated Answer: Leucippus and Democritus
# True Answer: Leucippus
# Best Combined Score (Similarity x Confidence): 3.0576863044584033
#
# Processed question 7:
# Generated Answer: Leucippus and Democritus
# True Answer: Leucippus
# Similarity: 3.0576863044584033
#
# Query: Which position did Enid Blyton beat the man who is the U.S. Representative for New York's 3rd district to win?
# Best Generated Answer: U.S. Representative for New York's 3rd district
# True Answer: Nassau County Executive
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 8:
# Generated Answer: U.S. Representative for New York's 3rd district
# True Answer: Nassau County Executive
# Similarity: 0.0
#
# Query: What religion is the composer for India's first science fiction film series?
# Best Generated Answer: Malayalam
# True Answer: Hindi
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 9:
# Generated Answer: Malayalam
# True Answer: Hindi
# Similarity: 0.0
#
# Query: The founder of this Canadian owned, American manufacturer of business jets for civilian and military developed this portable tape system.
# Best Generated Answer: 8-track cartridge
# True Answer: 8-track
# Best Combined Score (Similarity x Confidence): 7.737482409676319
#
# Processed question 10:
# Generated Answer: 8-track cartridge
# True Answer: 8-track
# Similarity: 7.737482409676319
#
# Query: When is the football club which Stan Spinks played for founded
# Best Generated Answer: 1930s
# True Answer: in 1902
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 11:
# Generated Answer: 1930s
# True Answer: in 1902
# Similarity: 0.0
#
# Query: The publication of which magazine ended first, Right On! or Castle of Frankenstein?
# Best Generated Answer: Castle of Frankenstein
# True Answer: Castle of Frankenstein
# Best Combined Score (Similarity x Confidence): 14.468654632568363
#
# Processed question 12:
# Generated Answer: Castle of Frankenstein
# True Answer: Castle of Frankenstein
# Similarity: 14.468654632568363
#
# Query: Who coached the Indians and was the first Native American to win a gold metal his home country?
# Best Generated Answer:
# True Answer: Jim Thorpe
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 13:
# Generated Answer:
# True Answer: Jim Thorpe
# Similarity: -1.0
#
# Query: Who wrote more fictional works, Jim Thompson or Theodore H. White?
# Best Generated Answer: Jim Rasenberger
# True Answer: Thompson
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 14:
# Generated Answer: Jim Rasenberger
# True Answer: Thompson
# Similarity: 0.0
#
# Query: Sum 41 and Passion Pit have what in common?
# Best Generated Answer: rock band
# True Answer: Passion Pit is an American indietronica band
# Best Combined Score (Similarity x Confidence): 1.7493161701485347
#
# Processed question 15:
# Generated Answer: rock band
# True Answer: Passion Pit is an American indietronica band
# Similarity: 1.7493161701485347
#
# Query: Which player for the Chicago American Gears held the record which George Harry Yardley III broke
# Best Generated Answer: George Harry Yardley III
# True Answer: George Lawrence Mikan, Jr.
# Best Combined Score (Similarity x Confidence): 0.6705768603057659
#
# Processed question 16:
# Generated Answer: George Harry Yardley III
# True Answer: George Lawrence Mikan, Jr.
# Similarity: 0.6705768603057659
#
# Query: Deyemi Okanlawon was in a music viideo by a Nigerian rapper who began his career with what group?
# Best Generated Answer: highlife
# True Answer: The School Boys
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 17:
# Generated Answer: highlife
# True Answer: The School Boys
# Similarity: 0.0
#
# Query: Baraki Barak District is situated in the western part of a province whose capital is what?
# Best Generated Answer: Logar
# True Answer: Puli Alam
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 18:
# Generated Answer: Logar
# True Answer: Puli Alam
# Similarity: 0.0
#
# Query: What play was written by Evgeny Schwartz and directed by Benno Besson?
# Best Generated Answer:
# True Answer: "The Dragon"
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 19:
# Generated Answer:
# True Answer: "The Dragon"
# Similarity: -1.0
#
# Query: Who brewed the first espresso coffee in space, Patrick Baudry or Samantha Cristoforetti?
# Best Generated Answer: Samantha Cristoforetti
# True Answer: Samantha Cristoforetti
# Best Combined Score (Similarity x Confidence): 10.457033157348635
#
# Processed question 20:
# Generated Answer: Samantha Cristoforetti
# True Answer: Samantha Cristoforetti
# Similarity: 10.457033157348635
#
# Query: Yves Apollinaire Pede made sand paintings of which South African anti-apartheid revolutionary?
# Best Generated Answer: Nelson Mandela
# True Answer: Nelson Mandela
# Best Combined Score (Similarity x Confidence): 12.968224525451664
#
# Processed question 21:
# Generated Answer: Nelson Mandela
# True Answer: Nelson Mandela
# Similarity: 12.968224525451664
#
# Query: Which city is the home of the character that might be based on John Capozzi?
# Best Generated Answer: New South Wales
# True Answer: Baltimore
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 22:
# Generated Answer: New South Wales
# True Answer: Baltimore
# Similarity: 0.0
#
# Query: What MLB pitcher nicknamed "Gander" was written about in "the Stratton Story">?
# Best Generated Answer: Monty Stratton
# True Answer: Monty Franklin Pierce Stratton
# Best Combined Score (Similarity x Confidence): 7.257081684392608
#
# Processed question 23:
# Generated Answer: Monty Stratton
# True Answer: Monty Franklin Pierce Stratton
# Similarity: 7.257081684392608
#
# Query: Harrison Newey made his ADAC Formula 4 debut with a partner who is the son of who?
# Best Generated Answer: Michael Schumacher
# True Answer: Corinna and seven-time Formula One World Champion Michael Schumacher
# Best Combined Score (Similarity x Confidence): 5.650449511967916
#
# Processed question 24:
# Generated Answer: Michael Schumacher
# True Answer: Corinna and seven-time Formula One World Champion Michael Schumacher
# Similarity: 5.650449511967916
#
# Query: Were Max Jacob and Connie May Fowler both memoirists?
# Best Generated Answer:
# True Answer: no
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 25:
# Generated Answer:
# True Answer: no
# Similarity: -1.0
#
# Query: What was the population during the 2000 census of the town in Sagadahoc County, Maine that had a population of 3,411 during the 2010 census?
# Best Generated Answer: 3,411
# True Answer: 1,864
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 26:
# Generated Answer: 3,411
# True Answer: 1,864
# Similarity: 0.0
#
# Query: Are both American bands The Four Seasons and Local H popular around the Beatles were around?
# Best Generated Answer: 1965 to 1969 on ABC in the U.S
# True Answer: no
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 27:
# Generated Answer: 1965 to 1969 on ABC in the U.S
# True Answer: no
# Similarity: 0.0
#
# Query: Who used a Barrack buster to shoot down a British Army Lynx helicopter
# Best Generated Answer: A unit of the IRA's South Armagh Brigade
# True Answer: IRA
# Best Combined Score (Similarity x Confidence): 2.5874223751043974
#
# Processed question 28:
# Generated Answer: A unit of the IRA's South Armagh Brigade
# True Answer: IRA
# Similarity: 2.5874223751043974
#
# Query: The Clavivox was invented by an American composer who was born Harry Warnow in what year?
# Best Generated Answer:
# True Answer: 1908
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 29:
# Generated Answer:
# True Answer: 1908
# Similarity: -1.0
#
# Query: In what year was the university where Sergei Aleksandrovich Tokarev was a professor founded?
# Best Generated Answer:
# True Answer: 1755
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 30:
# Generated Answer:
# True Answer: 1755
# Similarity: -1.0
#
# Query: Where is the company that owns thanKing Horse pub restaurant chain based ?
# Best Generated Answer: Bury St Edmunds, Suffolk, England
# True Answer: Bury St Edmunds,
# Best Combined Score (Similarity x Confidence): 9.761985203952797
#
# Processed question 31:
# Generated Answer: Bury St Edmunds, Suffolk, England
# True Answer: Bury St Edmunds,
# Similarity: 9.761985203952797
#
# Query: Which magazine is based out of more countries, Adventist World or Baseball Digest?
# Best Generated Answer: Adventist World
# True Answer: Adventist World
# Best Combined Score (Similarity x Confidence): 11.464344024658205
#
# Processed question 32:
# Generated Answer: Adventist World
# True Answer: Adventist World
# Similarity: 11.464344024658205
#
# Query: Roy Holder appeared in a 1967 film which was based on a play of the same name written by who?
# Best Generated Answer: Taming of the Shrew
# True Answer: William Shakespeare
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 33:
# Generated Answer: Taming of the Shrew
# True Answer: William Shakespeare
# Similarity: 0.0
#
# Query: Who is the author of the series in which Rupert Grint plays one of the three main characters?
# Best Generated Answer:
# True Answer: J. K. Rowling
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 34:
# Generated Answer:
# True Answer: J. K. Rowling
# Similarity: -1.0
#
# Query: What company founded in 1886 has owned the K-Y brand?
# Best Generated Answer: Johnson & Johnson
# True Answer: Johnson & Johnson
# Best Combined Score (Similarity x Confidence): 13.82933235168457
#
# Processed question 35:
# Generated Answer: Johnson & Johnson
# True Answer: Johnson & Johnson
# Similarity: 13.82933235168457
#
# Query: Ho Iat Seng  is a member of a legislative assembly that has how many members ?
# Best Generated Answer: Legislative Assembly of Macau
# True Answer: 33-member
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 36:
# Generated Answer: Legislative Assembly of Macau
# True Answer: 33-member
# Similarity: 0.0
#
# Query: Which genus contains more species, Ortegocactus or Eschscholzia?
# Best Generated Answer: Echinocactus
# True Answer: Eschscholzia
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 37:
# Generated Answer: Echinocactus
# True Answer: Eschscholzia
# Similarity: 0.0
#
# Query: Between Aspidistra and Cyrtanthus, which genus of plant belongs to the Subfamily Amaryllidoideae?
# Best Generated Answer: Cyrtanthus
# True Answer: Cyrtanthus
# Best Combined Score (Similarity x Confidence): 10.827699661254883
#
# Processed question 38:
# Generated Answer: Cyrtanthus
# True Answer: Cyrtanthus
# Similarity: 10.827699661254883
#
# Query: Which number in the Final Fantasy series was created by Hiroyuki Ito and allows the player control of the artificial intelligence of the characters in battle?
# Best Generated Answer:
# True Answer: Final Fantasy XII
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 39:
# Generated Answer:
# True Answer: Final Fantasy XII
# Similarity: -1.0
#
# Query: Which actor in the film Equus is also in the film The Informers?
# Best Generated Answer: Richard Burton
# True Answer: Colin Blakely
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 40:
# Generated Answer: Richard Burton
# True Answer: Colin Blakely
# Similarity: 0.0
#
# Query: While Jennifer Granholm was the Govenor of Michigan from 2003-2011, Ray Wert was responsible for doing what for her?
# Best Generated Answer: gubernatorial election
# True Answer: senior staffer
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 41:
# Generated Answer: gubernatorial election
# True Answer: senior staffer
# Similarity: 0.0
#
# Query: At which university did the notable psychoanalyst associated with the University of Chicago serve most of his career as a professor of psychiatry?
# Best Generated Answer: State University of New York Upstate Medical University
# True Answer: University of New York Upstate
# Best Combined Score (Similarity x Confidence): 12.862841382676695
#
# Processed question 42:
# Generated Answer: State University of New York Upstate Medical University
# True Answer: University of New York Upstate
# Similarity: 12.862841382676695
#
# Query: In what year was the Golden State NBA player, who was part of the Cavaliers-Warriors rivalry, named NBA Finals Most Valuable Player?
# Best Generated Answer: 2017the Cavaliers have won one, in 2016
# True Answer: 2015
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 43:
# Generated Answer: 2017the Cavaliers have won one, in 2016
# True Answer: 2015
# Similarity: 0.0
#
# Query: E! Hollywood Hold'em was hosted by a poker player of what nationality?
# Best Generated Answer: Phil Laak
# True Answer: Irish
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 44:
# Generated Answer: Phil Laak
# True Answer: Irish
# Similarity: 0.0
#
# Query: Bridge of Spies stars a Soviet intelligence officer with what name?
# Best Generated Answer: Bridge of Spies stars a Soviet intelligence officer with what name? Sheppard
# True Answer: Rudolf Abel
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 45:
# Generated Answer: Bridge of Spies stars a Soviet intelligence officer with what name? Sheppard
# True Answer: Rudolf Abel
# Similarity: 0.0
#
# Query: Martin Patterson "Pat" Hingle was a close friend of an actor who achieved success in what Western TV series?
# Best Generated Answer: On the Waterfront
# True Answer: Rawhide
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 46:
# Generated Answer: On the Waterfront
# True Answer: Rawhide
# Similarity: 0.0
#
# Query: Hardley Flood is an area of lagoons that support populations of the waterfowl that are a medium sized version of what animal?
# Best Generated Answer:
# True Answer: duck
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 47:
# Generated Answer:
# True Answer: duck
# Similarity: -1.0
#
# Query: What retailer in ABQ Uptown is headquarted in Poole, Dorset, United Kingdom?
# Best Generated Answer: Selfridges
# True Answer: Lush Ltd.
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 48:
# Generated Answer: Selfridges
# True Answer: Lush Ltd.
# Similarity: 0.0
#
# Query: What is the manufacturer of the car used by the Ford CD2 platform's design inspiration?
# Best Generated Answer:
# True Answer: Mazda
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 49:
# Generated Answer:
# True Answer: Mazda
# Similarity: -1.0
#
# Query: "A Summer in the Cage" and "American Hardcore" are both what kind of film?
# Best Generated Answer: crime drama
# True Answer: documentary
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 50:
# Generated Answer: crime drama
# True Answer: documentary
# Similarity: 0.0
#
# Query: In which event did Tyson Gay and Rodney Martin both represent the United States at the 2008 Beijing Olympics?
# Best Generated Answer: 4 x 100 metre relay
# True Answer: 4 x 100 metre relay
# Best Combined Score (Similarity x Confidence): 12.265515327453617
#
# Processed question 51:
# Generated Answer: 4 x 100 metre relay
# True Answer: 4 x 100 metre relay
# Similarity: 12.265515327453617
#
# Query: Who is from farther west, Kings of Convenience or Belle and Sebastian?
# Best Generated Answer: Gugu Mbatha-Raw
# True Answer: Belle and Sebastian
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 52:
# Generated Answer: Gugu Mbatha-Raw
# True Answer: Belle and Sebastian
# Similarity: 0.0
#
# Query: What major landform lended its name to both the Blue Ridge Music Center, and American's longest linear park?
# Best Generated Answer: Blue Ridge Parkway
# True Answer: 469 mi
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 53:
# Generated Answer: Blue Ridge Parkway
# True Answer: 469 mi
# Similarity: 0.0
#
# Query: IS Paul Sloane noted for directing more musicals than  Jacques Demy
# Best Generated Answer: Demy's films are celebrated for their sumptuous visual style
# True Answer: no
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 54:
# Generated Answer: Demy's films are celebrated for their sumptuous visual style
# True Answer: no
# Similarity: 0.0
#
# Query: What is the middle name of the Silicon Valley entrepreneur disussed in the non-fiction book The Unwinding?
# Best Generated Answer:
# True Answer: Andreas
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 55:
# Generated Answer:
# True Answer: Andreas
# Similarity: -1.0
#
# Query: Lauri Markkanen was traded for which player who was born in Houston?
# Best Generated Answer: Jimmy Butler
# True Answer: Jimmy Butler III
# Best Combined Score (Similarity x Confidence): 8.696744967908685
#
# Processed question 56:
# Generated Answer: Jimmy Butler
# True Answer: Jimmy Butler III
# Similarity: 8.696744967908685
#
# Query: Barnstable County Hospital was the location of the autopsy of the son of President John F. Kennedy and Jacqueline Kennedy, and the younger brother of who?
# Best Generated Answer:
# True Answer: Caroline Kennedy
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 57:
# Generated Answer:
# True Answer: Caroline Kennedy
# Similarity: -1.0
#
# Query: Who sang lead vocals on the Oasis hit single which had an acoustic debut in drummer Tony McCarroll's last concert ?
# Best Generated Answer: Tony McCarroll
# True Answer: Noel Gallagher
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 58:
# Generated Answer: Tony McCarroll
# True Answer: Noel Gallagher
# Similarity: 0.0
#
# Query: Ryan Fredericks plays for a professional football club based in which city ?
# Best Generated Answer: Hull City
# True Answer: London
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 59:
# Generated Answer: Hull City
# True Answer: London
# Similarity: 0.0
#
# Query: What song was on an American radio network that is owned by Disney Channels Worldwide, Inc. is a song by Senegalese-American R&B and rapper Akon?
# Best Generated Answer: Akon
# True Answer: "Lonely"
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 60:
# Generated Answer: Akon
# True Answer: "Lonely"
# Similarity: 0.0
#
# Query: Which South African anti-apartheid archbishop was part of the actions against the ruling National Party government?
# Best Generated Answer: Desmond Tutu
# True Answer: Desmond Mpilo Tutu
# Best Combined Score (Similarity x Confidence): 9.436980506116418
#
# Processed question 61:
# Generated Answer: Desmond Tutu
# True Answer: Desmond Mpilo Tutu
# Similarity: 9.436980506116418
#
# Query: Are Local H and For Against both from the United States?
# Best Generated Answer: Local H
# True Answer: yes
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 62:
# Generated Answer: Local H
# True Answer: yes
# Similarity: -0.0
#
# Query: Dawn Lake described the star of "I Love Lucy" as what?
# Best Generated Answer: American actress, comedienne
# True Answer: our greatest comedienne
# Best Combined Score (Similarity x Confidence): 2.3796872000687355
#
# Processed question 63:
# Generated Answer: American actress, comedienne
# True Answer: our greatest comedienne
# Similarity: 2.3796872000687355
#
# Query: What pop band features an Argentine actress that appeared in the television series "Chiquititas"?
# Best Generated Answer: Erreway
# True Answer: Erreway
# Best Combined Score (Similarity x Confidence): 17.890823364257812
#
# Processed question 64:
# Generated Answer: Erreway
# True Answer: Erreway
# Similarity: 17.890823364257812
#
# Query: In addition to Richard Strauss, Luigi Nono, Krzysztof Penderecki, Joaquín Rodrigo, and the German composer whose known for "Das Marienleben", what other composers have been represented by ESZ since the 1950s?
# Best Generated Answer: Richard Strauss, Luigi Nono, Krzysztof Penderecki, Joaquín Rodrigo
# True Answer: Igor Stravinsky, Carl Orff
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 65:
# Generated Answer: Richard Strauss, Luigi Nono, Krzysztof Penderecki, Joaquín Rodrigo
# True Answer: Igor Stravinsky, Carl Orff
# Similarity: 0.0
#
# Query: What year was the singer of "Orange" born?
# Best Generated Answer:
# True Answer: 1975
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 66:
# Generated Answer:
# True Answer: 1975
# Similarity: -1.0
#
# Query: Which opera was performed first, Thaïs or Euryanthe?
# Best Generated Answer: Euryanthe
# True Answer: Euryanthe
# Best Combined Score (Similarity x Confidence): 13.52518367767334
#
# Processed question 67:
# Generated Answer: Euryanthe
# True Answer: Euryanthe
# Similarity: 13.52518367767334
#
# Query: What 1944 Bollywood film was the mother of Bollywood actor Govinda in?
# Best Generated Answer: Barua
# True Answer: Geet or The Song
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 68:
# Generated Answer: Barua
# True Answer: Geet or The Song
# Similarity: 0.0
#
# Query: Goldilocks and the Three Bares was a film that was totally separate from the fairy tale from what century?
# Best Generated Answer:
# True Answer: 19th-century
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 69:
# Generated Answer:
# True Answer: 19th-century
# Similarity: -1.0
#
# Query: Which movie directed by James Gunn portrayed the fictional character, Ego the Living Planet?
# Best Generated Answer: Which movie directed by James Gunn portrayed the fictional character, Ego the Living Planet? He then started working also as a director, starting with "Slither
# True Answer: Guardians of the Galaxy Vol. 2
# Best Combined Score (Similarity x Confidence): 0.313967590788932
#
# Processed question 70:
# Generated Answer: Which movie directed by James Gunn portrayed the fictional character, Ego the Living Planet? He then started working also as a director, starting with "Slither
# True Answer: Guardians of the Galaxy Vol. 2
# Similarity: 0.313967590788932
#
# Query: What does the organization associated with Carl Wieland believe about anything other than the young earth view?
# Best Generated Answer: Creationist
# True Answer: a compromise on biblical inerrancy
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 71:
# Generated Answer: Creationist
# True Answer: a compromise on biblical inerrancy
# Similarity: 0.0
#
# Query: The 2017–18 Wigan Athletic F.C. season will be a year in which the team competes in the league cup known as what for sponsorship reasons?
# Best Generated Answer: The 2017–18 Wigan Athletic F.C. season will be a year in which the team competes in the league cup known as what for sponsorship reasons? season was the club's 29th season in the Football League and their second season in the Premier League
# True Answer: Carabao Cup
# Best Combined Score (Similarity x Confidence): 0.0009760797202131623
#
# Processed question 72:
# Generated Answer: The 2017–18 Wigan Athletic F.C. season will be a year in which the team competes in the league cup known as what for sponsorship reasons? season was the club's 29th season in the Football League and their second season in the Premier League
# True Answer: Carabao Cup
# Similarity: 0.0009760797202131623
#
# Query:  Inglis Barracks bombing was the first IRA attack in England since a bombing thats purpose was to kill what leader?
# Best Generated Answer: Brighton Bombing
# True Answer: Prime Minister Margaret Thatcher
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 73:
# Generated Answer: Brighton Bombing
# True Answer: Prime Minister Margaret Thatcher
# Similarity: 0.0
#
# Query: Are both Arizona v. United States and Reynolds v. United States Supreme Court cases?
# Best Generated Answer: Supreme Court cases
# True Answer: yes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 74:
# Generated Answer: Supreme Court cases
# True Answer: yes
# Similarity: 0.0
#
# Query: What is the name of the conditions that the radiologist who served as chief of radiology at the U.S. Army's flagship medical center from 1909 to 2011?
# Best Generated Answer:
# True Answer: Hampton's hump and Hampton's line
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 75:
# Generated Answer:
# True Answer: Hampton's hump and Hampton's line
# Similarity: -1.0
#
# Query: Are both Dafeng District and Dazhou located in the same province?
# Best Generated Answer:
# True Answer: no
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 76:
# Generated Answer:
# True Answer: no
# Similarity: -1.0
#
# Query: What type of word play does "What Are Little Girls Made Of?" and "What Are Little Boys Made Of?" have in common?
# Best Generated Answer: What type of word play does "What Are Little Girls Made Of?" and "What Are Little Boys Made Of?" have in common? It has a Roud Folk Song
# True Answer: rhyme
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 77:
# Generated Answer: What type of word play does "What Are Little Girls Made Of?" and "What Are Little Boys Made Of?" have in common? It has a Roud Folk Song
# True Answer: rhyme
# Similarity: -0.0
#
# Query: Which album was released first, "Talk That Talk" or "Loud"?
# Best Generated Answer: Talk That Talk
# True Answer: Loud
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 78:
# Generated Answer: Talk That Talk
# True Answer: Loud
# Similarity: 0.0
#
# Query: Dorothy Sarnoff's personal client list included what AMerican novelist, who has sold over 800 million copies of her books?
# Best Generated Answer: Danielle Steel
# True Answer: Danielle Fernandes Dominique Schuelein-Steel
# Best Combined Score (Similarity x Confidence): 7.197936368936033
#
# Processed question 79:
# Generated Answer: Danielle Steel
# True Answer: Danielle Fernandes Dominique Schuelein-Steel
# Similarity: 7.197936368936033
#
# Query: Mesih Pasha's uncle became emperor in what year?
# Best Generated Answer:
# True Answer: 1449
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 80:
# Generated Answer:
# True Answer: 1449
# Similarity: -1.0
#
# Query: where is the Vanderbilt mansion which Ochre Point–Cliffs Historic District is its home located
# Best Generated Answer: Ochre Point–Cliffs Historic District
# True Answer: Ochre Point Avenue
# Best Combined Score (Similarity x Confidence): 3.548434581828404
#
# Processed question 81:
# Generated Answer: Ochre Point–Cliffs Historic District
# True Answer: Ochre Point Avenue
# Similarity: 3.548434581828404
#
# Query: After his curacy at the village that is a suburb of Scunthorpe, who was Industrial Chaplain to the Bishop of Lincoln?
# Best Generated Answer:
# True Answer: Dudman
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 82:
# Generated Answer:
# True Answer: Dudman
# Similarity: -1.0
#
# Query: In what county did Michael Ola attend high school?
# Best Generated Answer: Madison County
# True Answer: Clayton County, Georgia, United States
# Best Combined Score (Similarity x Confidence): 1.762362069743467
#
# Processed question 83:
# Generated Answer: Madison County
# True Answer: Clayton County, Georgia, United States
# Similarity: 1.762362069743467
#
# Query: what did the second largest city by population in vietnam also serve as in the first indochina war?
# Best Generated Answer: Anti-French Resistance
# True Answer: Viet Minh's base
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 84:
# Generated Answer: Anti-French Resistance
# True Answer: Viet Minh's base
# Similarity: 0.0
#
# Query: John ruskin named his album due to a removal of what?
# Best Generated Answer: forename
# True Answer: marker pen
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 85:
# Generated Answer: forename
# True Answer: marker pen
# Similarity: 0.0
#
# Query: The Memphis Hustle are based in a suburb of a city with a population of what in 2010?
# Best Generated Answer: Southaven
# True Answer: 48,982
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 86:
# Generated Answer: Southaven
# True Answer: 48,982
# Similarity: -0.0
#
# Query: What year was the recipient of the 2016 Best Footballer in Asia born?
# Best Generated Answer:
# True Answer: 1986
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 87:
# Generated Answer:
# True Answer: 1986
# Similarity: -1.0
#
# Query: The last Republic serial made about a superhero stars what actor in the title role?
# Best Generated Answer: Nicholas D'Agosto
# True Answer: Richard Gerald "Dick" Purcell Jr.
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 88:
# Generated Answer: Nicholas D'Agosto
# True Answer: Richard Gerald "Dick" Purcell Jr.
# Similarity: 0.0
#
# Query: Prominent Danish Tibetologist Per Kjeld Sørensen is a professor of Central Asian Studies at Leipzig University that was founded by who?
# Best Generated Answer: Prominent Danish Tibetologist Per Kjeld Sørensen is a professor of Central Asian Studies at Leipzig University that was founded by who? He earned UGC Emeritus Fellowship in Central Asian Studies 1978-88, and was awarded by the President and Vice President of India
# True Answer: Frederick I, Elector of Saxony
# Best Combined Score (Similarity x Confidence): 0.40599994837426706
#
# Processed question 89:
# Generated Answer: Prominent Danish Tibetologist Per Kjeld Sørensen is a professor of Central Asian Studies at Leipzig University that was founded by who? He earned UGC Emeritus Fellowship in Central Asian Studies 1978-88, and was awarded by the President and Vice President of India
# True Answer: Frederick I, Elector of Saxony
# Similarity: 0.40599994837426706
#
# Query: Who was born first, Lawrence Ferlinghetti or Luigi Pirandello?
# Best Generated Answer: Luigi Pirandello
# True Answer: Luigi Pirandello
# Best Combined Score (Similarity x Confidence): 11.00508785247803
#
# Processed question 90:
# Generated Answer: Luigi Pirandello
# True Answer: Luigi Pirandello
# Similarity: 11.00508785247803
#
# Query: Milo Parker starred in which 2014 movie alongside Gillian Anderson?
# Best Generated Answer: Robot Overlords
# True Answer: Robot Overlords
# Best Combined Score (Similarity x Confidence): 0.8897417783737185
#
# Processed question 91:
# Generated Answer: Robot Overlords
# True Answer: Robot Overlords
# Similarity: 0.8897417783737185
#
# Query: How many total staff (including part-time, flexible, and fixed contract staff) does the broadcaster, who released HyperNormalisation, employ?
# Best Generated Answer: 35,402
# True Answer: 35,402
# Best Combined Score (Similarity x Confidence): 16.870708465576175
#
# Processed question 92:
# Generated Answer: 35,402
# True Answer: 35,402
# Similarity: 16.870708465576175
#
# Query: Who did the 39th Vice President of the United States serve under?
# Best Generated Answer: Gerald Rudolph Ford Jr
# True Answer: Richard Nixon
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 93:
# Generated Answer: Gerald Rudolph Ford Jr
# True Answer: Richard Nixon
# Similarity: 0.0
#
# Query: When was the anthology, in which fisrt pages of The Incal" were released, created?
# Best Generated Answer:
# True Answer: December 1974
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 94:
# Generated Answer:
# True Answer: December 1974
# Similarity: -1.0
#
# Query: Which movie is loosley based off the Brother Grimm's "Iron Henry"?
# Best Generated Answer: The Trap
# True Answer: The Frog Prince
# Best Combined Score (Similarity x Confidence): 0.9667589557767238
#
# Processed question 95:
# Generated Answer: The Trap
# True Answer: The Frog Prince
# Similarity: 0.9667589557767238
#
# Query: Both José Aponte de la Torre Airport and Boulder City Municipal Airport are classified as what type of airport?
# Best Generated Answer: public use airport
# True Answer: public use airport
# Best Combined Score (Similarity x Confidence): 10.904684066772463
#
# Processed question 96:
# Generated Answer: public use airport
# True Answer: public use airport
# Similarity: 10.904684066772463
#
# Query: The Northern Circuit dates from a year when a King of England married to whom sent his justices on circuit?
# Best Generated Answer: Henry II
# True Answer: Eleanor of Aquitaine
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 97:
# Generated Answer: Henry II
# True Answer: Eleanor of Aquitaine
# Similarity: 0.0
#
# Query: Where did the military engagements that Captain Lewis Cunningham Broadus served during take place?
# Best Generated Answer: United States Army
# True Answer: Mexico-United States border region
# Best Combined Score (Similarity x Confidence): 2.4937900545344895
#
# Processed question 98:
# Generated Answer: United States Army
# True Answer: Mexico-United States border region
# Similarity: 2.4937900545344895
#
# Query: In which year was this English singer, songwriter, musician, activist and a co-founder of the Beatles born, whose classmate Bill Harry founded Mersey Beat at Liverpool Art College?
# Best Generated Answer: John Lennon
# True Answer: 19408
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 99:
# Generated Answer: John Lennon
# True Answer: 19408
# Similarity: 0.0
#
# Query: What is the name of  rocker, who was awarded "Rock Goddess of the Year" in the Annual Loudwide Music Awards, who sang with high pitched screams in her band's albums?
# Best Generated Answer: Brandy Lynn Clark
# True Answer: Maria Brink
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 100:
# Generated Answer: Brandy Lynn Clark
# True Answer: Maria Brink
# Similarity: 0.0
#
# Query: Which Oxford University graduate did Midge Mackenzie interview in "Women Talking"?
# Best Generated Answer: Kate Millett
# True Answer: Kate Millett
# Best Combined Score (Similarity x Confidence): 12.986126899719242
#
# Processed question 101:
# Generated Answer: Kate Millett
# True Answer: Kate Millett
# Similarity: 12.986126899719242
#
# Query: what year did the band that sang Gives You Hell form?
# Best Generated Answer:
# True Answer: 1999
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 102:
# Generated Answer:
# True Answer: 1999
# Similarity: -1.0
#
# Query: What movie studio produced The Benchwarmers, which starred Rob Schneider and Napoleon Dynamites lead actor, Jon Heder?
# Best Generated Answer: Revolution Studios
# True Answer: Revolution Studios
# Best Combined Score (Similarity x Confidence): 16.927103042602543
#
# Processed question 103:
# Generated Answer: Revolution Studios
# True Answer: Revolution Studios
# Similarity: 16.927103042602543
#
# Query: Who directed the nuclear war drama where Rita May played Jimmy Kemp's mother?
# Best Generated Answer: Lloyd Corrigan
# True Answer: Mick Jackson
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 104:
# Generated Answer: Lloyd Corrigan
# True Answer: Mick Jackson
# Similarity: 0.0
#
# Query: Which had a bigger population in the 2016 census: Queens or Staten Island?
# Best Generated Answer: Staten Island
# True Answer: Queens
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 105:
# Generated Answer: Staten Island
# True Answer: Queens
# Similarity: 0.0
#
# Query: Which actress does this Netflix's project by Nick Bernardone and Tina Fey star in the title role?
# Best Generated Answer: Mía Maestro
# True Answer: Ellie Kemper
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 106:
# Generated Answer: Mía Maestro
# True Answer: Ellie Kemper
# Similarity: 0.0
#
# Query: What is the brand who makes canned meats that had its own cook off in Austin until 2007?
# Best Generated Answer: The Indian Packing Company
# True Answer: Hormel Foods Corporation
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 107:
# Generated Answer: The Indian Packing Company
# True Answer: Hormel Foods Corporation
# Similarity: 0.0
#
# Query: Which has more species in Asia, Disporum or Boltonia?
# Best Generated Answer: Disporum
# True Answer: Disporum
# Best Combined Score (Similarity x Confidence): 12.324263572692871
#
# Processed question 108:
# Generated Answer: Disporum
# True Answer: Disporum
# Similarity: 12.324263572692871
#
# Query: The structure in Wyoming in which Bořeň is similar to has a summit that is how many feet above sea level?
# Best Generated Answer: 13,804 feet
# True Answer: 5,112 feet
# Best Combined Score (Similarity x Confidence): 3.897354751066271
#
# Processed question 109:
# Generated Answer: 13,804 feet
# True Answer: 5,112 feet
# Similarity: 3.897354751066271
#
# Query: Who was born first Iain Pears or Richard Llewellyn ?
# Best Generated Answer: Richard Dafydd Vivian Llewellyn Lloyd
# True Answer: Richard Dafydd Vivian Llewellyn
# Best Combined Score (Similarity x Confidence): 6.780253673059292
#
# Processed question 110:
# Generated Answer: Richard Dafydd Vivian Llewellyn Lloyd
# True Answer: Richard Dafydd Vivian Llewellyn
# Similarity: 6.780253673059292
#
# Query: WHICH GROUP OF PEOPLE NICKNAMED THE US ARMYS REGIMENT "BUFFALO SOLDIERS" IN WHICH THOMAS SHAW WON THE MEDAL OF HONOR DURING THE INDIAN WARS?
# Best Generated Answer: Buffalo Soldier
# True Answer: Native American tribes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 111:
# Generated Answer: Buffalo Soldier
# True Answer: Native American tribes
# Similarity: 0.0
#
# Query: When was the American singer, songwriter, actress and LGBT rights activist born who won Grammy and Emmy award?
# Best Generated Answer: When was the American singer, songwriter, actress and LGBT rights activist born who won Grammy and Emmy award? They recognized accomplishments by musicians from the previous year
# True Answer: June 22, 1953
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 112:
# Generated Answer: When was the American singer, songwriter, actress and LGBT rights activist born who won Grammy and Emmy award? They recognized accomplishments by musicians from the previous year
# True Answer: June 22, 1953
# Similarity: -0.0
#
# Query: "Knock" is an example of fiction by Frederic Brown that has how many words?
# Best Generated Answer: less than 2000 words
# True Answer: 1000 words
# Best Combined Score (Similarity x Confidence): 2.4991000095904305
#
# Processed question 113:
# Generated Answer: less than 2000 words
# True Answer: 1000 words
# Similarity: 2.4991000095904305
#
# Query: Christopher Oscar Pena was recognized by an entertainment-industry brand aimed at what?
# Best Generated Answer: American financier and film producer
# True Answer: people working in film and the performing arts
# Best Combined Score (Similarity x Confidence): 1.9002379608502395
#
# Processed question 114:
# Generated Answer: American financier and film producer
# True Answer: people working in film and the performing arts
# Similarity: 1.9002379608502395
#
# Query: Both Truth in Science and Discovery embrace what campaign?
# Best Generated Answer: Teach the Controversy
# True Answer: "Teach the Controversy" campaign
# Best Combined Score (Similarity x Confidence): 6.675732540376983
#
# Processed question 115:
# Generated Answer: Teach the Controversy
# True Answer: "Teach the Controversy" campaign
# Similarity: 6.675732540376983
#
# Query: "Call Me Mañana" is a song by a group that has sold how many records?
# Best Generated Answer: "Call Me Mañana" is a song by a group that has sold how many records? It was released on August 15, 1994
# True Answer: over 30 million
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 116:
# Generated Answer: "Call Me Mañana" is a song by a group that has sold how many records? It was released on August 15, 1994
# True Answer: over 30 million
# Similarity: -0.0
#
# Query: James Garner had a role in the 2004 romantic drama directed by whom?
# Best Generated Answer: James Garner had a role in the 2004 romantic drama directed by whom? Monica Anna Maria Bellucci
# True Answer: Nick Cassavetes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 117:
# Generated Answer: James Garner had a role in the 2004 romantic drama directed by whom? Monica Anna Maria Bellucci
# True Answer: Nick Cassavetes
# Similarity: 0.0
#
# Query: A 2005 computer animated short film by Pixar, and directed by an American director that was born in 1957, is based on what film?
# Best Generated Answer: Lifted
# True Answer: The Incredibles
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 118:
# Generated Answer: Lifted
# True Answer: The Incredibles
# Similarity: 0.0
#
# Query: The youngest daughter of Lady Mary-Gaye Curzon stars with Douglas Smith and Lucien Laviscount  in what 2017 film?
# Best Generated Answer: The Viceroy's Daughters: The Lives of the Curzon Sisters
# True Answer: The Bye Bye Man
# Best Combined Score (Similarity x Confidence): 0.603292531730279
#
# Processed question 119:
# Generated Answer: The Viceroy's Daughters: The Lives of the Curzon Sisters
# True Answer: The Bye Bye Man
# Similarity: 0.603292531730279
#
# Query: The Prodigal Daughter, though a book about an American, is by a novelist of what nationality?
# Best Generated Answer: Jeffrey Archer
# True Answer: English
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 120:
# Generated Answer: Jeffrey Archer
# True Answer: English
# Similarity: 0.0
#
# Query: What production company is owned by the director of "She Hate Me"?
# Best Generated Answer: Vikram Bhatt
# True Answer: 40 Acres and a Mule Filmworks
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 121:
# Generated Answer: Vikram Bhatt
# True Answer: 40 Acres and a Mule Filmworks
# Similarity: 0.0
#
# Query: For which Thomas Rickman film did Sissy Spacek win an Academy Award for Best Actress?
# Best Generated Answer: Winter's Bone
# True Answer: Coal Miner's Daughter
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 122:
# Generated Answer: Winter's Bone
# True Answer: Coal Miner's Daughter
# Similarity: 0.0
#
# Query: Boulevardier and Earthquake are cocktails, one of which has a french nickname of what?
# Best Generated Answer: hair of the dog
# True Answer: The Tremblement de Terre
# Best Combined Score (Similarity x Confidence): 0.5394774538085103
#
# Processed question 123:
# Generated Answer: hair of the dog
# True Answer: The Tremblement de Terre
# Similarity: 0.5394774538085103
#
# Query: What kind of building did the Romans use that is still the most common architectural style for churches in Europe and America?
# Best Generated Answer: Western architecture
# True Answer: basilica
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 124:
# Generated Answer: Western architecture
# True Answer: basilica
# Similarity: 0.0
#
# Query: Adena Friedman was formerly the managing director and CFO of a company that specializes in what four key business areas?
# Best Generated Answer: real estate
# True Answer: corporate private equity, real assets, global market strategies, and investment solutions.
# Best Combined Score (Similarity x Confidence): 0.2582513922678158
#
# Processed question 125:
# Generated Answer: real estate
# True Answer: corporate private equity, real assets, global market strategies, and investment solutions.
# Similarity: 0.2582513922678158
#
# Query: One of the signatories of the Chicago Statement on Biblical Inerrancy was which Presbyterian pastor, known for taking a more presuppositional approach to apologetics?
# Best Generated Answer: James Montgomery Boice
# True Answer: Francis Schaeffer
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 126:
# Generated Answer: James Montgomery Boice
# True Answer: Francis Schaeffer
# Similarity: 0.0
#
# Query: What was the name of the Danish musician who died in 1931 and who composed String Quartet No. 4 in F major or Quartet for Two Violins, Viola and Cello in F major, Opus 44 ?
# Best Generated Answer: Carl Nielsen
# True Answer: Carl August Nielsen
# Best Combined Score (Similarity x Confidence): 10.660270308626664
#
# Processed question 127:
# Generated Answer: Carl Nielsen
# True Answer: Carl August Nielsen
# Similarity: 10.660270308626664
#
# Query: Who was the original recording artist of the song which was chosen over If You've Got Trouble for the Beatles' "Help!" film?
# Best Generated Answer: Lennon–McCartney
# True Answer: Buck Owens
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 128:
# Generated Answer: Lennon–McCartney
# True Answer: Buck Owens
# Similarity: 0.0
#
# Query: Who is older Carrie Akre or Shifty Shellshock?
# Best Generated Answer: Carrie Akre
# True Answer: Carrie Akre
# Best Combined Score (Similarity x Confidence): 10.534526824951174
#
# Processed question 129:
# Generated Answer: Carrie Akre
# True Answer: Carrie Akre
# Similarity: 10.534526824951174
#
# Query: The  Actaea genus is native to what continent that the Onoclea genus is not?
# Best Generated Answer: North America
# True Answer: Europe
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 130:
# Generated Answer: North America
# True Answer: Europe
# Similarity: 0.0
#
# Query: Which star on the Mexican telenovela "Amy, la niña de la mochila azul" is also a singer, model, fashion designer, and recording artist?
# Best Generated Answer: Danna Paola
# True Answer: Danna Paola
# Best Combined Score (Similarity x Confidence): 6.403488159179689
#
# Processed question 131:
# Generated Answer: Danna Paola
# True Answer: Danna Paola
# Similarity: 6.403488159179689
#
# Query: The song "Chim Chim Cher-ee" can be heard  in the "Mary Poppins" scene of a Disney ride that debuted in what year?
# Best Generated Answer: The Great Movie Ride at Disney's Hollywood Studios and during the "Mary Poppins" segment of "" at Disneyland
# True Answer: 1989
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 132:
# Generated Answer: The Great Movie Ride at Disney's Hollywood Studios and during the "Mary Poppins" segment of "" at Disneyland
# True Answer: 1989
# Similarity: 0.0
#
# Query: Shirley Breeden won her first Senate term in a narrow upset over the politician who was a member of what branch of the armed forces?
# Best Generated Answer:
# True Answer: U.S. Army
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 133:
# Generated Answer:
# True Answer: U.S. Army
# Similarity: -1.0
#
# Query: Are Ganzhou and Jimo District both located in China?
# Best Generated Answer: People's Republic of China
# True Answer: yes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 134:
# Generated Answer: People's Republic of China
# True Answer: yes
# Similarity: 0.0
#
# Query: What famous composer leveraged microtonal music and unconventional methods of musicianship to create his contemporary reknown?
# Best Generated Answer: Benjamin Burwell Johnston, Jr
# True Answer: Ben Johnston
# Best Combined Score (Similarity x Confidence): 1.5115655011374578
#
# Processed question 135:
# Generated Answer: Benjamin Burwell Johnston, Jr
# True Answer: Ben Johnston
# Similarity: 1.5115655011374578
#
# ...
# Similarity: 10.639056205749513
#
# Query: Which one of Ricardo Rodríguez Saá's relatives would become governor from 1983 to 2001?
# Best Generated Answer: Adolfo Rodríguez Saá
# True Answer: Adolfo Rodríguez Saá
# Best Combined Score (Similarity x Confidence): 4.006009101867677
#
# Processed question 366:
# Generated Answer: Adolfo Rodríguez Saá
# True Answer: Adolfo Rodríguez Saá
# Similarity: 4.006009101867677
#
# Query: The British diver featured in Splash! specializes in what event?
# Best Generated Answer: DJ/Producer
# True Answer: 10-metre platform event
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 367:
# Generated Answer: DJ/Producer
# True Answer: 10-metre platform event
# Similarity: 0.0
#
# Query: Which Canadian artist is credited with first coming up with the title of Various Positions?
# Best Generated Answer: Dolores Claman
# True Answer: Leonard Cohen
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 368:
# Generated Answer: Dolores Claman
# True Answer: Leonard Cohen
# Similarity: 0.0
#
# Query: Which author influenced the animated Easter television special "The First Easter Rabbit"?
# Best Generated Answer: Margery Williams
# True Answer: Margery Williams
# Best Combined Score (Similarity x Confidence): 12.523607254028324
#
# Processed question 369:
# Generated Answer: Margery Williams
# True Answer: Margery Williams
# Similarity: 12.523607254028324
#
# Query: What kind of material forms the wrapping for the chocolate candies that Hershey Kissables were shaped like?
# Best Generated Answer:
# True Answer: aluminum foil
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 370:
# Generated Answer:
# True Answer: aluminum foil
# Similarity: -1.0
#
# Query: Which was secretary to President Richard Nixon: Rose Mary Woods or H. R. Haldeman?
# Best Generated Answer: Rose Mary Woods
# True Answer: Rose Mary Woods
# Best Combined Score (Similarity x Confidence): 16.092197418212894
#
# Processed question 371:
# Generated Answer: Rose Mary Woods
# True Answer: Rose Mary Woods
# Similarity: 16.092197418212894
#
# Query: The most famous song of the last monarch of Hawaii was what?
# Best Generated Answer: Aloha ʻOe
# True Answer: Aloha ʻOe
# Best Combined Score (Similarity x Confidence): 17.53142356872559
#
# Processed question 372:
# Generated Answer: Aloha ʻOe
# True Answer: Aloha ʻOe
# Similarity: 17.53142356872559
#
# Query: What NFL team did the 2017 ESPN College Football Friday Primetime host who played at Oklahoma in college play for?
# Best Generated Answer: There is no main sponsor
# True Answer: the Bears
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 373:
# Generated Answer: There is no main sponsor
# True Answer: the Bears
# Similarity: -0.0
#
# Query: Who designed the building that the 58th Technology & Engineering Emmy Awards were held in?
# Best Generated Answer:
# True Answer: Designed by KlingStubbins
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 374:
# Generated Answer:
# True Answer: Designed by KlingStubbins
# Similarity: -1.0
#
# Query: What series was Emily Bergl in that is set in Chicago?
# Best Generated Answer: Counterpart", "Da Vinci's Demons", "Person of Interest", "Eureka", "Leverage", and "The 4400
# True Answer: Shameless
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 375:
# Generated Answer: Counterpart", "Da Vinci's Demons", "Person of Interest", "Eureka", "Leverage", and "The 4400
# True Answer: Shameless
# Similarity: 0.0
#
# Query: Who is the Chief Executive Officer of the corporation that owns Space Dev?
# Best Generated Answer:
# True Answer: Fatih Ozmen
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 376:
# Generated Answer:
# True Answer: Fatih Ozmen
# Similarity: -1.0
#
# Query: When was the folk dance style Johannes Brahms' Liebeslieder Waltzes were written for most popular?
# Best Generated Answer: first performance
# True Answer: end of the 18th century
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 377:
# Generated Answer: first performance
# True Answer: end of the 18th century
# Similarity: 0.0
#
# Query: What is the name of second extended play by the artists of the mini-abum Code#01?
# Best Generated Answer: Small Soldiers
# True Answer: Code#02 Pretty Pretty
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 378:
# Generated Answer: Small Soldiers
# True Answer: Code#02 Pretty Pretty
# Similarity: 0.0
#
# Query: Which suburb is a soap opera featuring a character named Beverly Marshall set in?
# Best Generated Answer: Neighbours
# True Answer: Erinsborough
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 379:
# Generated Answer: Neighbours
# True Answer: Erinsborough
# Similarity: 0.0
#
# Query: The former British protectorate of Rhodesia became two countries with the Zambezi river as the border. Zimbabwe lies to the south; which country is north of the river?
# Best Generated Answer: North-Eastern Rhodesia
# True Answer: Zambia
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 380:
# Generated Answer: North-Eastern Rhodesia
# True Answer: Zambia
# Similarity: 0.0
#
# Query: Is the building located at 200 West Street taller than the one at 888 7th Avenue?
# Best Generated Answer: 888 7th Avenue
# True Answer: yes
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 381:
# Generated Answer: 888 7th Avenue
# True Answer: yes
# Similarity: 0.0
#
# Query: Pablo Jose Ozuna is the cousin of a Dominican professional baseball left fielder who made his MLB debut in what year?
# Best Generated Answer:
# True Answer: 2013
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 382:
# Generated Answer:
# True Answer: 2013
# Similarity: -1.0
#
# Query: What company was Luca Cordero di Montezemolo the chairman of that merged into a new Netherlands-based holding company Fiat Chrysler Automobiles NV?
# Best Generated Answer: Fiat S.p.A
# True Answer: Fabbrica Italiana Automobili Torino
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 383:
# Generated Answer: Fiat S.p.A
# True Answer: Fabbrica Italiana Automobili Torino
# Similarity: 0.0
#
# Query: When was the  Australian competition NSWRL formed in which H Kaufman was a rugby league player?
# Best Generated Answer:
# True Answer: 8 August 1907
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 384:
# Generated Answer:
# True Answer: 8 August 1907
# Similarity: -1.0
#
# Query: Which Persian historical figure was an astronomer, Al-Karaji or Ahmad Nahavandi?
# Best Generated Answer: Ali Qushji
# True Answer: Ahmad
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 385:
# Generated Answer: Ali Qushji
# True Answer: Ahmad
# Similarity: 0.0
#
# Query: Who produced the 1998 British comedy starring the director of the feature film "Eddie the Eagle"?
# Best Generated Answer:
# True Answer: Matthew Vaughn
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 386:
# Generated Answer:
# True Answer: Matthew Vaughn
# Similarity: -1.0
#
# Query: How many albums did the company who released Tift Merritt's debut album release for Tif Merritt?
# Best Generated Answer:
# True Answer: two
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 387:
# Generated Answer:
# True Answer: two
# Similarity: -1.0
#
# Query: Cyrina Fiallo has guest starred on which Michael Jacobs-created sitcom?
# Best Generated Answer: DeCavalcante crime family
# True Answer: Girl Meets World
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 388:
# Generated Answer: DeCavalcante crime family
# True Answer: Girl Meets World
# Similarity: 0.0
#
# Query: What has David Bowie done in The Lodge?
# Best Generated Answer: What has David Bowie done in The Lodge? David Bowie (often referred to as David Bowie Box or Bowie Box Set) is a box set
# True Answer: mastered recordings
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 389:
# Generated Answer: What has David Bowie done in The Lodge? David Bowie (often referred to as David Bowie Box or Bowie Box Set) is a box set
# True Answer: mastered recordings
# Similarity: -0.0
#
# Query: Which singer is younger, Shirley Manson or Jim Kerr?
# Best Generated Answer: Marilyn Manson
# True Answer: Shirley Ann Manson
# Best Combined Score (Similarity x Confidence): 2.9503001787614354
#
# Processed question 390:
# Generated Answer: Marilyn Manson
# True Answer: Shirley Ann Manson
# Similarity: 2.9503001787614354
#
# Query: What is the year of the event that occured first, Making Today a Perfect Day was produced, or Frozen was produced?
# Best Generated Answer:
# True Answer: 2013
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 391:
# Generated Answer:
# True Answer: 2013
# Similarity: -1.0
#
# Query: Edward Marszewski is the editor-in-chief of Lumpen, who is the editor-in-chief of Saveur?
# Best Generated Answer: Edward Marszewski
# True Answer: Colman Andrews
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 392:
# Generated Answer: Edward Marszewski
# True Answer: Colman Andrews
# Similarity: -0.0
#
# Query: Beyond the Edge was a docudrama about the mountaineer that was part of the Everest expedition led by whom?
# Best Generated Answer: Robert Edwin "Rob" Hall
# True Answer: John Hunt
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 393:
# Generated Answer: Robert Edwin "Rob" Hall
# True Answer: John Hunt
# Similarity: 0.0
#
# Query: Which American band was formed the earliest, CKY or Violent Femmes?
# Best Generated Answer: Violent Femmes
# True Answer: Violent Femmes
# Best Combined Score (Similarity x Confidence): 8.478755950927736
#
# Processed question 394:
# Generated Answer: Violent Femmes
# True Answer: Violent Femmes
# Similarity: 8.478755950927736
#
# Query: The eastern coast of Ivan Zammit's birth city is located along what body of water?
# Best Generated Answer: Messalonskee Lake
# True Answer: Grand Harbour
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 395:
# Generated Answer: Messalonskee Lake
# True Answer: Grand Harbour
# Similarity: 0.0
#
# Query: In the British experimental jazz band Polar Bear, who handles digital devices?
# Best Generated Answer: Leafcutter John
# True Answer: Leafcutter John
# Best Combined Score (Similarity x Confidence): 18.04537963867188
#
# Processed question 396:
# Generated Answer: Leafcutter John
# True Answer: Leafcutter John
# Similarity: 18.04537963867188
#
# Query: In what state is the manufacturer of Bisquick headquartered?
# Best Generated Answer: New Jersey
# True Answer: Minnesota
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 397:
# Generated Answer: New Jersey
# True Answer: Minnesota
# Similarity: 0.0
#
# Query: which is larger Asante Traditional Buildings or Gulangyu?
# Best Generated Answer: Asante Traditional Buildings
# True Answer: Gulangyu
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 398:
# Generated Answer: Asante Traditional Buildings
# True Answer: Gulangyu
# Similarity: 0.0
#
# Query: When the two Coldplay songs U.F.O and Princess of China were written, what factor did they have in common?
# Best Generated Answer: written by all four members of the band for their fifth studio album, "Mylo Xyloto
# True Answer: was written by all four members of the band
# Best Combined Score (Similarity x Confidence): 2.8845462755275904
#
# Processed question 399:
# Generated Answer: written by all four members of the band for their fifth studio album, "Mylo Xyloto
# True Answer: was written by all four members of the band
# Similarity: 2.8845462755275904
#
# Query: Before moving to Boston to play at the New England Patriots, in which city did Dean Caliguire play his college and NFL football?
# Best Generated Answer: Pittsburgh Steelers
# True Answer: Pittsburgh
# Best Combined Score (Similarity x Confidence): 4.564406767036434
#
# Processed question 400:
# Generated Answer: Pittsburgh Steelers
# True Answer: Pittsburgh
# Similarity: 4.564406767036434
#
# Query: What genre of music was played by both Tappi Tíkarrass and INXS?
# Best Generated Answer: funk, rock and jazz
# True Answer: rock
# Best Combined Score (Similarity x Confidence): 1.8644431392215215
#
# Processed question 401:
# Generated Answer: funk, rock and jazz
# True Answer: rock
# Similarity: 1.8644431392215215
#
# Query: What career did the British actor born in 1965  and star of Lock, Stock and Two Smoking Barrels have before acting?
# Best Generated Answer: guest starring in "The Bill
# True Answer: professional footballer
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 402:
# Generated Answer: guest starring in "The Bill
# True Answer: professional footballer
# Similarity: 0.0
#
# Query: Suicide's 1977 released album features a song based on what brand's comic character?
# Best Generated Answer: Suicide's 1977 released album features a song based on what brand's comic character? Records
# True Answer: Marvel
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 403:
# Generated Answer: Suicide's 1977 released album features a song based on what brand's comic character? Records
# True Answer: Marvel
# Similarity: -0.0
#
# Query: Ernest Foot was the best friend of the fighter pilot who had how many victories?
# Best Generated Answer: Richard Ira Bong
# True Answer: 44
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 404:
# Generated Answer: Richard Ira Bong
# True Answer: 44
# Similarity: 0.0
#
# Query: Did Minersville School District v. Gobitis and Gravel v. United States occur in the same decade?
# Best Generated Answer: Minersville School District
# True Answer: no
# Best Combined Score (Similarity x Confidence): -0.0
#
# Processed question 405:
# Generated Answer: Minersville School District
# True Answer: no
# Similarity: -0.0
#
# Query: Having written singles for several country acts, including Randy Travis, Blake Shelton, and Keith Whitley, what singer song writer achieved his 3rd No 1 single by writing "Always and Forever"?
# Best Generated Answer: Paul Overstreet
# True Answer: Paul Overstreet
# Best Combined Score (Similarity x Confidence): 12.833408355712894
#
# Processed question 406:
# Generated Answer: Paul Overstreet
# True Answer: Paul Overstreet
# Similarity: 12.833408355712894
#
# Query: Which continent have a distribution of both the Ternstroemia and Cussonia genus of plants?
# Best Generated Answer:
# True Answer: Africa
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 407:
# Generated Answer:
# True Answer: Africa
# Similarity: -1.0
#
# Query:  Which album did the band Kraftwerk release after their successful album which reached number 25 on the US "Billboard" Hot 100 chart?
# Best Generated Answer: Tour de France Soundtracks
# True Answer: Radio-Activity
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 408:
# Generated Answer: Tour de France Soundtracks
# True Answer: Radio-Activity
# Similarity: 0.0
#
# Query: Angelo Francesco Lavignino scored a 1965 English-language Spanish-Swiss co-produced film that was directed by and also starred who?
# Best Generated Answer: Alain Jessua
# True Answer: Orson Welles
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 409:
# Generated Answer: Alain Jessua
# True Answer: Orson Welles
# Similarity: 0.0
#
# Query: What was the population of the city where Penobscot Marine Museum is located?
# Best Generated Answer:
# True Answer: The population was 2,615
# Best Combined Score (Similarity x Confidence): -1.0
#
# Processed question 410:
# Generated Answer:
# True Answer: The population was 2,615
# Similarity: -1.0
#
# Query: Which player signed to Bayern Munich before the 2012-2013 season was known mostly as a central defender?
# Best Generated Answer: Javi Martínez
# True Answer: Dante
# Best Combined Score (Similarity x Confidence): 0.0
#
# Processed question 411:
# Generated Answer: Javi Martínez
# True Answer: Dante
# Similarity: 0.0
#
# Query: Midland F1 Racing was a racing team that, in 2007, competed under what name for sponsorship reasons?
# Best Generated Answer: Spyker F1
# True Answer: Spyker F1
# Best Combined Score (Similarity x Confidence): 18.13973426818848
#
# Processed question 412:
# Generated Answer: Spyker F1
# True Answer: Spyker F1
# Similarity: 18.13973426818848

# %%
print(sim1)
count=0
for i in sim1:
  if i>=1:
    count+=1
print(count/len(sim1))

# %% [markdown]
# # Second evaluation on our proposed model, as trained in "model_training.ipynb", with average similarity and Exact Match (EM) calculations, using a slightly different method.

# %%
sim1=[]
def answer_query_with_context4(query, true_answer, pinecone_index, top_k=5, min_similarity_threshold=0.2):
    """
    Retrieve the top contexts from Pinecone, check context relevance, split them into smaller chunks,
    evaluate each chunk with the QA model, and return the best answer based on combined score.

    Args:
        query (str): The question/query.
        true_answer (str): The true answer for comparison.
        pinecone_index: The Pinecone index object for retrieving contexts.
        top_k (int): The number of top contexts to retrieve from Pinecone.
        min_similarity_threshold (float): Minimum similarity score to consider context relevant.

    Returns:
        Tuple: (best_generated_answer, best_combined_score) - best answer and its similarity score.
    """
    # Encode the query
    query_embedding = embedding_model.encode(query)
    query_vector = [float(val) for val in query_embedding]

    # Retrieve top contexts from Pinecone
    query_results = pinecone_index.query(
        vector=query_vector,
        top_k=top_k,
        include_values=True,
        include_metadata=True
    )['matches']

    best_generated_answer = ""
    best_combined_score = -1.0

    # Filter irrelevant contexts before passing to QA model
    for match in query_results:
        context = match['metadata']['context']
        context_embedding = embedding_model.encode(context)
        similarity = cosine_similarity([query_embedding], [context_embedding])[0][0]

        # Skip contexts with low relevance to the query
        if similarity < min_similarity_threshold:
            continue

        # Split context into smaller chunks (e.g., sentences)
        sentences = context.split(". ")
        for sentence in sentences:
            # Tokenize the question and context chunk
            inputs = tokenizer(query, sentence, return_tensors="pt", max_length=512, truncation=True)

            # Perform inference
            with torch.no_grad():
                outputs = model(**inputs)
                start_logits = outputs.start_logits
                end_logits = outputs.end_logits

                # Get the most probable start and end positions
                start_idx = torch.argmax(start_logits)
                end_idx = torch.argmax(end_logits)

                if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
                    generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
                else:
                    generated_answer = ""

                if generated_answer:
                    # Calculate similarity between generated and true answer
                    vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
                    similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]

                    # Calculate confidence and combined score
                    confidence = (start_logits[0][start_idx] + end_logits[0][end_idx]).item()
                    combined_score = similarity * confidence

                    # Track the best answer
                    if combined_score > best_combined_score:
                        best_generated_answer = generated_answer
                        best_combined_score = combined_score

    return best_generated_answer, best_combined_score

def save_first_100_answers_from_hotpotqa3(hotpotqa_data, pinecone_index, file_name="qa_results.json"):
    results = []

    for i in range(len(hotpotqa_data)):
        query = hotpotqa_data[i]["question"]
        true_answer = hotpotqa_data[i]["answer"]

        generated_answer, similarity = answer_query_with_context4(query, true_answer, pinecone_index)

        results.append({
            "question": query,
            "true_answer": true_answer,
            "generated_answer": generated_answer,
            "similarity": similarity
        })

        print(f"Processed question {i+1}:")
        print(f"Generated Answer: {generated_answer}")
        print(f"True Answer: {true_answer}")
        print(f"Best Combined Score (Similarity x Confidence): {similarity}\n")
        sim1.append(similarity)

    with open(file_name, "w") as f:
        json.dump(results, f, indent=4)
    print(f"Results saved to {file_name}")

# Example usage:
# Assuming `dataset` is loaded with HotpotQA data and `index` is your Pinecone index
save_first_100_answers_from_hotpotqa3(dataset, pinecone_index=index)
print(np.mean(sim1))

# %%
print(sim1)
count=0
for i in sim1:
  if i>=1:
    count+=1
print(count/len(sim1))

# %%
print(sim1)

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 73642}},
#  'total_vector_count': 73642}

# %% [markdown]
# # Evaluation on BERT model, and DeBERTa model, with average similarity and Exact Match (EM) calculations.

# %%
import numpy as np
import json
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import torch

# Initialize a list to store similarity scores
sim1 = []

def answer_query_with_context4(query, true_answer, pinecone_index, model, tokenizer, embedding_model, top_k=5, min_similarity_threshold=0.2):
    """
    Retrieve the top contexts from Pinecone, check context relevance, split them into smaller chunks,
    evaluate each chunk with the QA model, and return the best answer based on combined score.

    Args:
        query (str): The question/query.
        true_answer (str): The true answer for comparison.
        pinecone_index: The Pinecone index object for retrieving contexts.
        model: The model to use for generating answers.
        tokenizer: The tokenizer corresponding to the model.
        embedding_model: The embedding model for context relevance.
        top_k (int): The number of top contexts to retrieve from Pinecone.
        min_similarity_threshold (float): Minimum similarity score to consider context relevant.

    Returns:
        Tuple: (best_generated_answer, best_combined_score) - best answer and its similarity score.
    """
    # Encode the query
    query_embedding = embedding_model.encode(query)
    query_vector = [float(val) for val in query_embedding]

    # Retrieve top contexts from Pinecone
    query_results = pinecone_index.query(
        vector=query_vector,
        top_k=top_k,
        include_values=True,
        include_metadata=True
    )['matches']

    best_generated_answer = ""
    best_combined_score = -1.0

    # Filter irrelevant contexts before passing to QA model
    for match in query_results:
        context = match['metadata']['context']
        context_embedding = embedding_model.encode(context)
        similarity = cosine_similarity([query_embedding], [context_embedding])[0][0]

        # Skip contexts with low relevance to the query
        if similarity < min_similarity_threshold:
            continue

        # Split context into smaller chunks (e.g., sentences)
        sentences = context.split(". ")
        for sentence in sentences:
            # Tokenize the question and context chunk
            inputs = tokenizer(query, sentence, return_tensors="pt", max_length=512, truncation=True)

            # Perform inference
            with torch.no_grad():
                outputs = model(**inputs)
                start_logits = outputs.start_logits
                end_logits = outputs.end_logits

                # Get the most probable start and end positions
                start_idx = torch.argmax(start_logits)
                end_idx = torch.argmax(end_logits)

                if start_idx < end_idx and end_idx < inputs['input_ids'].size(1):
                    generated_answer = tokenizer.decode(inputs['input_ids'][0][start_idx:end_idx + 1], skip_special_tokens=True)
                else:
                    generated_answer = ""

                if generated_answer:
                    # Calculate similarity between generated and true answer
                    vectorizer = TfidfVectorizer().fit_transform([generated_answer, true_answer])
                    similarity = cosine_similarity(vectorizer[0:1], vectorizer[1:2]).flatten()[0]

                    # Calculate confidence and combined score
                    confidence = (start_logits[0][start_idx] + end_logits[0][end_idx]).item()
                    combined_score = similarity * confidence

                    # Track the best answer
                    if combined_score > best_combined_score:
                        best_generated_answer = generated_answer
                        best_combined_score = combined_score

    return best_generated_answer, best_combined_score

def save_first_100_answers_from_hotpotqa3(hotpotqa_data, pinecone_index, model, tokenizer, embedding_model, file_name="qa_results.json"):
    results = []

    for i in range(100):
        query = hotpotqa_data[i]["question"]
        true_answer = hotpotqa_data[i]["answer"]

        generated_answer, similarity = answer_query_with_context4(query, true_answer, pinecone_index, model, tokenizer, embedding_model)

        results.append({
            "question": query,
            "true_answer": true_answer,
            "generated_answer": generated_answer,
            "similarity": similarity
        })

        print(f"Processed question {i + 1}:")
        print(f"Generated Answer: {generated_answer}")
        print(f"True Answer: {true_answer}")
        print(f"Best Combined Score (Similarity x Confidence): {similarity}\n")
        sim1.append(similarity)

    with open(file_name, "w") as f:
        json.dump(results, f, indent=4)
    print(f"Results saved to {file_name}")


from transformers import BertTokenizer, BertForQuestionAnswering, DebertaTokenizer, DebertaForQuestionAnswering

bert_model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

deberta_model = DebertaForQuestionAnswering.from_pretrained("microsoft/deberta-base")
deberta_tokenizer = DebertaTokenizer.from_pretrained("microsoft/deberta-base")

save_first_100_answers_from_hotpotqa3(dataset, pinecone_index=index, model=bert_model, tokenizer=bert_tokenizer, embedding_model=embedding_model)
print("BERT Mean Similarity:", np.mean(sim1))

print(sim1)
count=0
for i in sim1:
  if i>=1:
    count+=1
print(count/len(sim1))

sim1.clear()

save_first_100_answers_from_hotpotqa3(dataset, pinecone_index=index, model=deberta_model, tokenizer=deberta_tokenizer, embedding_model=embedding_model)
print("DeBERTa Mean Similarity:", np.mean(sim1))

print(sim1)
count=0
for i in sim1:
  if i>=1:
    count+=1
print(count/len(sim1))
